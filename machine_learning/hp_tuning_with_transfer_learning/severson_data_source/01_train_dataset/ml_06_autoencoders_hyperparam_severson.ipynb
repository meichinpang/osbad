# %% [markdown]
# # Import libraries

# %%
# %load_ext autoreload
# %autoreload 2

# Standard library
from pathlib import Path
import pprint

# Third-party libraries
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import optuna

# Custom osbad library for anomaly detection
import osbad.config as bconf
import osbad.hyperparam as hp
import osbad.modval as modval
import osbad.viz as bviz
from osbad.database import BenchDB
from osbad.model import ModelRunner
# Out:
# /home/mei-chin-pang/02_academics/osbad_development/osbad/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:182: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# # Import dataset

# %%
# Define a global variable to save fig output
# The definition of PIPELINE_OUTPUT_DIR can be
# found in config.py
PIPELINE_OUTPUT_DIR = bconf.PIPELINE_OUTPUT_DIR

# Path to database directory
DB_DIR = bconf.DB_DIR

# Path to the DuckDB instance:
# "osbad/database/train_dataset_severson.db"
db_filepath = (
    DB_DIR.joinpath("train_dataset_severson.db"))

# %% [markdown]
# ## Get unique cell labels from training dataset

# %%
# Create a DuckDB connection
con = duckdb.connect(
    db_filepath,
    read_only=True)

# Load all training dataset from duckdb
df_duckdb = con.execute(
    "SELECT * FROM df_train_dataset_sv").fetchdf()

unique_cell_index_train = df_duckdb["cell_index"].unique()
print(unique_cell_index_train)
# Out:
# ['2017-05-12_5_4C-50per_3C_CH13' '2017-05-12_5_4C-50per_3C_CH14'
#  '2017-05-12_5_4C-60per_3C_CH15' '2017-05-12_5_4C-60per_3C_CH16'
#  '2017-05-12_5_4C-70per_3C_CH17' '2017-05-12_5_4C-70per_3C_CH18'
#  '2017-05-12_6C-40per_3C_CH25' '2017-05-12_6C-40per_3C_CH26'
#  '2017-05-12_6C-50per_3C_CH27' '2017-05-12_6C-50per_3C_CH28'
#  '2017-05-12_6C-60per_3C_CH29' '2017-05-12_6C-60per_3C_CH30'
#  '2017-05-12_7C-40per_3C_CH37' '2017-05-12_7C-40per_3C_CH38'
#  '2017-05-12_4C-80per_4C_CH5' '2017-05-12_4C-80per_4C_CH6'
#  '2017-05-12_4_4C-80per_4_4C_CH7' '2017-05-12_5_4C-80per_5_4C_CH11'
#  '2017-05-12_5_4C-80per_5_4C_CH12' '2017-05-12_3_6C-80per_3_6C_CH1'
#  '2017-05-12_3_6C-80per_3_6C_CH2' '2017-05-12_3_6C-80per_3_6C_CH3'
#  '2017-05-12_5_4C-40per_3_6C_CH19']

# %%
training_cell_count = len(unique_cell_index_train)
print(f"Training cell count: {training_cell_count}")
# Out:
# Training cell count: 23

# %% [markdown]
# ## Define selected_cell_label

# %%
# Get the cell-ID from cell_inventory
selected_cell_label = "2017-05-12_5_4C-70per_3C_CH17"

# Create a subfolder to store fig output
# corresponding to each cell-index
selected_cell_artifacts_dir = bconf.artifacts_output_dir(
    selected_cell_label)

# %% [markdown]
# # Load benchmarking dataset

# %%
# Import the BenchDB class
# Load only the dataset based on the selected cell
benchdb = BenchDB(
    db_filepath,
    selected_cell_label)

# load the benchmarking dataset
df_selected_cell = benchdb.load_benchmark_dataset(
    dataset_type="train")
# Out:
# Database is found in the given filepath.
# Loading benchmarking dataset now...
# ****************************************************************************************************

# %% [markdown]
# ## Drop labels

# %%
if df_selected_cell is not None:

    filter_col = [
        "cell_index",
        "cycle_index",
        "discharge_capacity",
        "voltage"]

    # Drop true labels from the benchmarking dataset
    # and filter for selected columns only
    df_selected_cell_without_labels = benchdb.drop_labels(
        df_selected_cell,
        filter_col)

    # print a subset of the dataframe
    # for diagnostics running in terminals
    print(df_selected_cell_without_labels.head(10).to_markdown())
    print("*"*100)
# Out:
# |    | cell_index                    |   cycle_index |   discharge_capacity |   voltage |
# |---:|:------------------------------|--------------:|---------------------:|----------:|
# |  0 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          1.26512e-05 |   3.29189 |
# |  1 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00136774  |   3.28185 |
# |  2 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00292998  |   3.27788 |
# |  3 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00449361  |   3.27513 |
# |  4 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00449361  |   3.27513 |
# |  5 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00605927  |   3.27299 |
# |  6 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00762155  |   3.27124 |
# |  7 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0091859   |   3.2703  |
# |  8 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0107469   |   3.26875 |
# |  9 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0123127   |   3.26787 |
# ****************************************************************************************************

# %% [markdown]
# ## Plot cycle data without labels

# %%
# If the true outlier cycle index is not known,
# cycling data will be plotted without labels
benchdb.plot_cycle_data(
    df_selected_cell_without_labels)

output_fig_filename = (
    "cycle_data_without_labels_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Features transformation

# %% [markdown]
# ## Load the training features dataset

# %%
# Define the filepath to ``train_features_severson.db``
# osbad/database/train_features_severson.db
db_features_filepath = (
    DB_DIR.joinpath(
        "train_features_severson.db"))

# Load only the training features dataset
df_features_per_cell = benchdb.load_features_db(
    db_features_filepath,
    dataset_type="train")

unique_cycle_count = (
    df_features_per_cell["cycle_index"].unique())
# Out:
# Features database is found in the given filepath.
# Features database is loaded.
# ****************************************************************************************************

# %%
df_features_per_cell
# Out:
#      max_diff_dQ  log_max_diff_dQ  cycle_index  max_diff_dV  log_max_diff_dV  \
# 0       0.006388        -5.053343          0.0     1.564151         0.447343
# 1       0.006338        -5.061258          1.0     0.023727        -3.741163
# 2       0.006321        -5.063922          2.0     0.022684        -3.786091
# 3       0.006259        -5.073756          3.0     0.027899        -3.579172
# 4       0.006236        -5.077346          4.0     0.026408        -3.634081
# ..           ...              ...          ...          ...              ...
# 687     0.006236        -5.077391        687.0     0.046420        -3.070023
# 688     0.006281        -5.070178        688.0     0.051542        -2.965352
# 689     0.006243        -5.076238        689.0     0.047776        -3.041228
# 690     0.006316        -5.064619        690.0     0.046331        -3.071935
# 691     0.006402        -5.051123        691.0     0.047873        -3.039193
#
#                         cell_index
# 0    2017-05-12_5_4C-70per_3C_CH17
# 1    2017-05-12_5_4C-70per_3C_CH17
# 2    2017-05-12_5_4C-70per_3C_CH17
# 3    2017-05-12_5_4C-70per_3C_CH17
# 4    2017-05-12_5_4C-70per_3C_CH17
# ..                             ...
# 687  2017-05-12_5_4C-70per_3C_CH17
# 688  2017-05-12_5_4C-70per_3C_CH17
# 689  2017-05-12_5_4C-70per_3C_CH17
# 690  2017-05-12_5_4C-70per_3C_CH17
# 691  2017-05-12_5_4C-70per_3C_CH17
#
# [692 rows x 6 columns]

# %% [markdown]
# # Hyperparameter tuning

# %% [markdown]
# ## Create optuna study

# %%
# Define the hyperparameter search space for Autoencoders
hp_space=lambda trial: {
    "batch_size": trial.suggest_int(
        "batch_size", 8, 32),
    "epoch_num": trial.suggest_int(
        "epoch_num", 10, 50),
    "learning_rate": trial.suggest_float(
        "learning_rate", 0.0, 0.1),
    "dropout_rate": trial.suggest_float(
        "dropout_rate", 0.1, 0.5),
    "threshold": trial.suggest_float(
        "threshold", 0.0, 1.0)}

# %%
# Instantiate an optuna study for autoencoder model
sampler = optuna.samplers.TPESampler(seed=42)

selected_feature_cols = (
    "log_max_diff_dQ",
    "log_max_diff_dV")

autoencoder_study = optuna.create_study(
    study_name="autoencoder_hyperparam",
    sampler=sampler,
    directions=["maximize","maximize"])

autoencoder_study.optimize(
    lambda trial: hp.objective(
        trial,
        model_id="autoencoder",
        df_feature_dataset=df_features_per_cell,
        selected_feature_cols=selected_feature_cols,
        df_benchmark_dataset=df_selected_cell,
        hp_space=hp_space,
        selected_cell_label=selected_cell_label),
    n_trials=20)
# Out:
# [I 2026-03-05 19:47:09,065] A new study created in memory with name: autoencoder_hyperparam
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:15<00:00,  3.11it/s]
# [I 2026-03-05 19:47:26,934] Trial 0 finished with values: [1.0, 1.0] and parameters: {'batch_size': 17, 'epoch_num': 48, 'learning_rate': 0.0731993941811405, 'dropout_rate': 0.3394633936788146, 'threshold': 0.15601864044243652}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:05<00:00,  2.40it/s]
# [I 2026-03-05 19:47:32,456] Trial 1 finished with values: [1.0, 1.0] and parameters: {'batch_size': 11, 'epoch_num': 12, 'learning_rate': 0.08661761457749352, 'dropout_rate': 0.34044600469728353, 'threshold': 0.7080725777960455}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 49/49 [00:11<00:00,  4.34it/s]
# [I 2026-03-05 19:47:44,367] Trial 2 finished with values: [1.0, 1.0] and parameters: {'batch_size': 8, 'epoch_num': 49, 'learning_rate': 0.08324426408004218, 'dropout_rate': 0.18493564427131048, 'threshold': 0.18182496720710062}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:06<00:00,  3.26it/s]
# [I 2026-03-05 19:47:51,606] Trial 3 finished with values: [1.0, 1.0] and parameters: {'batch_size': 12, 'epoch_num': 22, 'learning_rate': 0.052475643163223784, 'dropout_rate': 0.2727780074568463, 'threshold': 0.2912291401980419}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:03<00:00,  4.19it/s]
# [I 2026-03-05 19:47:55,630] Trial 4 finished with values: [1.0, 1.0] and parameters: {'batch_size': 23, 'epoch_num': 15, 'learning_rate': 0.029214464853521818, 'dropout_rate': 0.2465447373174767, 'threshold': 0.45606998421703593}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:03<00:00,  4.86it/s]
# [I 2026-03-05 19:47:59,764] Trial 5 finished with values: [1.0, 0.04] and parameters: {'batch_size': 27, 'epoch_num': 18, 'learning_rate': 0.05142344384136116, 'dropout_rate': 0.33696582754481696, 'threshold': 0.046450412719997725}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:03<00:00,  4.18it/s]
# [I 2026-03-05 19:48:04,046] Trial 6 finished with values: [0.5, 1.0] and parameters: {'batch_size': 23, 'epoch_num': 16, 'learning_rate': 0.006505159298527952, 'dropout_rate': 0.4795542149013333, 'threshold': 0.9656320330745594}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:02<00:00,  7.61it/s]
# [I 2026-03-05 19:48:07,346] Trial 7 finished with values: [1.0, 1.0] and parameters: {'batch_size': 28, 'epoch_num': 22, 'learning_rate': 0.009767211400638388, 'dropout_rate': 0.3736932106048628, 'threshold': 0.4401524937396013}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:04<00:00,  7.06it/s]
# [I 2026-03-05 19:48:12,005] Trial 8 finished with values: [1.0, 1.0] and parameters: {'batch_size': 11, 'epoch_num': 30, 'learning_rate': 0.0034388521115218396, 'dropout_rate': 0.4637281608315128, 'threshold': 0.2587799816000169}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:04<00:00,  4.99it/s]
# [I 2026-03-05 19:48:16,842] Trial 9 finished with values: [1.0, 1.0] and parameters: {'batch_size': 24, 'epoch_num': 22, 'learning_rate': 0.05200680211778108, 'dropout_rate': 0.31868411173731187, 'threshold': 0.18485445552552704}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:15<00:00,  3.17it/s]
# [I 2026-03-05 19:48:32,489] Trial 10 finished with values: [1.0, 0.008456659619450317] and parameters: {'batch_size': 17, 'epoch_num': 48, 'learning_rate': 0.0696117803358321, 'dropout_rate': 0.10718475024592788, 'threshold': 0.015367737328104342}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:04<00:00,  9.35it/s]
# [I 2026-03-05 19:48:37,037] Trial 11 finished with values: [0.75, 1.0] and parameters: {'batch_size': 17, 'epoch_num': 39, 'learning_rate': 0.09582159830319743, 'dropout_rate': 0.4014826977718555, 'threshold': 0.8615231333889454}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  6.73it/s]
# [I 2026-03-05 19:48:38,950] Trial 12 finished with values: [1.0, 1.0] and parameters: {'batch_size': 32, 'epoch_num': 10, 'learning_rate': 0.028585430844509926, 'dropout_rate': 0.13700118340430872, 'threshold': 0.7234437210371949}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34/34 [00:10<00:00,  3.18it/s]
# [I 2026-03-05 19:48:50,117] Trial 13 finished with values: [1.0, 1.0] and parameters: {'batch_size': 17, 'epoch_num': 34, 'learning_rate': 0.07422740597053112, 'dropout_rate': 0.2102017008803902, 'threshold': 0.6590789298483584}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 42/42 [00:07<00:00,  5.40it/s]
# [I 2026-03-05 19:48:58,356] Trial 14 finished with values: [1.0, 1.0] and parameters: {'batch_size': 31, 'epoch_num': 42, 'learning_rate': 0.02395294303910882, 'dropout_rate': 0.41579082652778593, 'threshold': 0.6163226069843143}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:11<00:00,  2.48it/s]
# [I 2026-03-05 19:49:10,575] Trial 15 finished with values: [0.5, 1.0] and parameters: {'batch_size': 13, 'epoch_num': 29, 'learning_rate': 0.09960165317474357, 'dropout_rate': 0.1684815593910434, 'threshold': 0.9855103175485851}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 42/42 [00:21<00:00,  1.96it/s]
# [I 2026-03-05 19:49:32,534] Trial 16 finished with values: [0.75, 1.0] and parameters: {'batch_size': 8, 'epoch_num': 42, 'learning_rate': 0.039509396966930316, 'dropout_rate': 0.24126621150328487, 'threshold': 0.7979948690790173}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:02<00:00,  3.64it/s]
# [I 2026-03-05 19:49:35,748] Trial 17 finished with values: [1.0, 1.0] and parameters: {'batch_size': 20, 'epoch_num': 10, 'learning_rate': 0.06544788491695348, 'dropout_rate': 0.44165019373096515, 'threshold': 0.5520728670887681}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34/34 [00:02<00:00, 13.51it/s]
# [I 2026-03-05 19:49:38,647] Trial 18 finished with values: [1.0, 1.0] and parameters: {'batch_size': 28, 'epoch_num': 34, 'learning_rate': 0.08528684404942775, 'dropout_rate': 0.3518161515540478, 'threshold': 0.3630810038985294}.
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:09<00:00,  4.92it/s]
# [I 2026-03-05 19:49:48,298] Trial 19 finished with values: [0.75, 1.0] and parameters: {'batch_size': 15, 'epoch_num': 45, 'learning_rate': 0.014729886833543183, 'dropout_rate': 0.28319249306791816, 'threshold': 0.8502368694232076}.

# %% [markdown]
# ## Aggregate best trials

# %%
schema_autoencoder = {
    "batch_size": "median_int",
    "epoch_num": "median_int",
    "learning_rate": "median",
    "dropout_rate": "median",
    "threshold": "median",
}

df_autoencoder_hyperparam = hp.aggregate_best_trials(
    autoencoder_study.best_trials,
    cell_label=selected_cell_label,
    model_id="autoencoder",
    schema=schema_autoencoder)

df_autoencoder_hyperparam
# Out:
#       ml_model                     cell_index  batch_size  epoch_num  \
# 0  autoencoder  2017-05-12_5_4C-70per_3C_CH17          20         22
#
#    learning_rate  dropout_rate  threshold
# 0       0.052476      0.339463   0.440152

# %% [markdown]
# ## Evaluate percentage of perfect recall and precision score

# %%
recall_score_pct, precision_score_pct = hp.evaluate_hp_perfect_score_pct(
    model_study=autoencoder_study)
# Out:
# Total trial count: 20
# Trial 0:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 1:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 2:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 3:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 4:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 5:
# Recall score per trial: 1.0
# Precision score per trial: 0.04
# ----------------------------------------------------------------------
# Trial 6:
# Recall score per trial: 0.5
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 7:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 8:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 9:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 10:
# Recall score per trial: 1.0
# Precision score per trial: 0.008456659619450317
# ----------------------------------------------------------------------
# Trial 11:
# Recall score per trial: 0.75
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 12:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 13:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 14:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 15:
# Recall score per trial: 0.5
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 16:
# Recall score per trial: 0.75
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 17:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 18:
# Recall score per trial: 1.0
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Trial 19:
# Recall score per trial: 0.75
# Precision score per trial: 1.0
# ----------------------------------------------------------------------
# Percentage perfect recall score: 75.0
# Percentage perfect precision score: 90.0
# ****************************************************************************************************

# %% [markdown]
# ## Plot pareto front

# %%
hp.plot_pareto_front(
    autoencoder_study,
    selected_cell_label,
    fig_title="Autoencoder Pareto Front")

plt.show()
# Out:
# /home/mei-chin-pang/02_academics/osbad_development/osbad/src/osbad/hyperparam.py:990: ExperimentalWarning: optuna.visualization.matplotlib._pareto_front.plot_pareto_front is experimental (supported from v2.8.0). The interface can change in the future.
#   axplot = optuna.visualization.matplotlib.plot_pareto_front(

# %% [markdown]
# ## Export current hyperparameters to CSV

# %%
# Export current hyperparameters to CSV
hyperparam_filepath =  Path.cwd().joinpath(
    "ml_06_autoencoders_hyperparam_severson.csv")

hp.export_current_hyperparam(
    df_autoencoder_hyperparam,
    selected_cell_label,
    export_csv_filepath=hyperparam_filepath,
    if_exists="replace")
# Out:
# Have the hyperparam for 2017-05-12_5_4C-70per_3C_CH17 been evaluated?
# True
# **********************************************************************
# Replacing existing rows for 2017-05-12_5_4C-70per_3C_CH17.
# Hyperparameters for 2017-05-12_5_4C-70per_3C_CH17 have been replaced in the CSV file.
#       ml_model                     cell_index  batch_size  epoch_num  \
# 0  autoencoder  2017-05-12_5_4C-70per_3C_CH17          20         22
#
#    learning_rate  dropout_rate  threshold
# 0       0.052476      0.339463   0.440152

# %% [markdown]
# # Train model with best trial parameters

# %% [markdown]
# ## Load best trial parameters from CSV output

# %%
# Test reading from exported metrics
df_hyperparam_from_csv = pd.read_csv(hyperparam_filepath)

df_param_per_cell = df_hyperparam_from_csv[
    df_hyperparam_from_csv["cell_index"] == selected_cell_label]
df_param_per_cell
# Out:
#       ml_model                     cell_index  batch_size  epoch_num  \
# 0  autoencoder  2017-05-12_5_4C-70per_3C_CH17          20         22
#
#    learning_rate  dropout_rate  threshold
# 0       0.052476      0.339463   0.440152

# %% [markdown]
# ## Create a dict for best trial parameters

# %%
param_dict = df_param_per_cell.iloc[0].to_dict()
pprint.pp(param_dict)
# Out:
# {'ml_model': 'autoencoder',
#  'cell_index': '2017-05-12_5_4C-70per_3C_CH17',
#  'batch_size': 20,
#  'epoch_num': 22,
#  'learning_rate': 0.0524756431632237,
#  'dropout_rate': 0.3394633936788146,
#  'threshold': 0.4401524937396013}

# %% [markdown]
# ## Run the model with best trial parameters

# %%
cfg = hp.MODEL_CONFIG["autoencoder"]

runner = ModelRunner(
    cell_label=selected_cell_label,
    df_input_features=df_features_per_cell,
    selected_feature_cols=selected_feature_cols
)

Xdata = runner.create_model_x_input()

model = cfg.model_param(param_dict)
print(model)
model.fit(Xdata)
proba = model.predict_proba(Xdata)

pred_outlier_indices, pred_outlier_score = runner.pred_outlier_indices_from_proba(
    proba=proba,
    threshold=param_dict["threshold"],
    outlier_col=cfg.proba_col
)

pred_outlier_indices, pred_outlier_score
# Out:
# AutoEncoder(batch_norm=True, batch_size=20, compile_mode='default',
#       contamination=0.1, device=device(type='cpu'),
#       dropout_rate=0.3394633936788146, epoch_num=22,
#       hidden_activation_name='relu',
#       hidden_neuron_list=[2, 64, 32, 32, 64, 2], lr=0.0524756431632237,
#       optimizer_name='adam', optimizer_params={'weight_decay': 1e-05},
#       preprocessing=True, random_state=42, use_compile=False, verbose=1)
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:05<00:00,  3.94it/s]
# (array([  0,  40, 147, 148]),
#  array([0.67881238, 0.76941937, 0.99734986, 1.        ]))

# %% [markdown]
# ## Get df_outliers_pred

# %%
df_outliers_pred = (df_features_per_cell[
    df_features_per_cell["cycle_index"]
    .isin(pred_outlier_indices)].copy())

df_outliers_pred["outlier_prob"] = pred_outlier_score
df_outliers_pred
# Out:
#      max_diff_dQ  log_max_diff_dQ  cycle_index  max_diff_dV  log_max_diff_dV  \
# 0       0.006388        -5.053343          0.0     1.564151         0.447343
# 40      0.006305        -5.066425         40.0     2.612268         0.960219
# 147     0.042814        -3.150895        147.0     0.029431        -3.525697
# 148     0.042899        -3.148905        148.0     0.025238        -3.679404
#
#                         cell_index  outlier_prob
# 0    2017-05-12_5_4C-70per_3C_CH17      0.678812
# 40   2017-05-12_5_4C-70per_3C_CH17      0.769419
# 147  2017-05-12_5_4C-70per_3C_CH17      0.997350
# 148  2017-05-12_5_4C-70per_3C_CH17      1.000000

# %% [markdown]
# ## Predict anomaly score map

# %%
axplot = runner.predict_anomaly_score_map(
    selected_model=model,
    model_name="Autoencoder",
    xoutliers=df_outliers_pred["log_max_diff_dQ"],
    youtliers=df_outliers_pred["log_max_diff_dV"],
    pred_outliers_index=pred_outlier_indices,
    threshold=param_dict["threshold"]
)

axplot.set_xlabel(
     r"$\log(\Delta Q_{\mathrm{scaled,max,cyc}})$ [Ah]",
     fontsize = 12)

axplot.set_ylabel(
     r"$\log(\Delta V_{\mathrm{scaled,max,cyc}})$ [V]",
     fontsize = 12)

output_fig_filename = (
    "autoencoder_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:06<00:00,  3.62it/s]

# %% [markdown]
# # Model performance evaluation

# %%
df_eval_outlier = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=pred_outlier_indices)

# %% [markdown]
# ## Confusion matrix

# %%
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier["true_outlier"],
    y_pred=df_eval_outlier["pred_outlier"])

axplot.set_title(
    "Autoencoder",
    fontsize=16)

output_fig_filename = (
    "conf_matrix_autoencoder_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Evaluate model performance

# %%
df_current_eval_metrics = modval.eval_model_performance(
    model_name="autoencoder",
    selected_cell_label=selected_cell_label,
    df_eval_outliers=df_eval_outlier)

df_current_eval_metrics
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# MCC-score: 1.0
# ****************************************************************************************************
#       ml_model                     cell_index  accuracy  precision  recall  \
# 0  autoencoder  2017-05-12_5_4C-70per_3C_CH17       1.0        1.0     1.0
#
#    f1_score  mcc_score
# 0       1.0        1.0

# %% [markdown]
# ## Export model performance metrics to CSV output

# %%
# Export current metrics to CSV
hyperparam_eval_filepath =  Path.cwd().joinpath(
    "eval_metrics_hp_single_cell_severson.csv")

hp.export_current_model_metrics(
    model_name="autoencoder",
    selected_cell_label=selected_cell_label,
    df_current_eval_metrics=df_current_eval_metrics,
    export_csv_filepath=hyperparam_eval_filepath,
    if_exists="replace")
# Out:
# Have the metrics for autoencoder on cell 2017-05-12_5_4C-70per_3C_CH17 been evaluated before?
# True
# ----------------------------------------------------------------------
# Replacing existing row for autoencoder, 2017-05-12_5_4C-70per_3C_CH17.
# Metrics for autoencoder, 2017-05-12_5_4C-70per_3C_CH17 have been replaced in the CSV file.
#       ml_model                     cell_index  accuracy  precision  recall  \
# 0      iforest  2017-05-12_5_4C-70per_3C_CH17       1.0        1.0     1.0
# 1          knn  2017-05-12_5_4C-70per_3C_CH17       1.0        1.0     1.0
# 2          gmm  2017-05-12_5_4C-70per_3C_CH17       1.0        1.0     1.0
# 3          lof  2017-05-12_5_4C-70per_3C_CH17       1.0        1.0     1.0
# 4          pca  2017-05-12_5_4C-70per_3C_CH17       1.0        1.0     1.0
# 5  autoencoder  2017-05-12_5_4C-70per_3C_CH17       1.0        1.0     1.0
#
#    f1_score  mcc_score
# 0       1.0        1.0
# 1       1.0        1.0
# 2       1.0        1.0
# 3       1.0        1.0
# 4       1.0        1.0
# 5       1.0        1.0

# %% [markdown]
# # Finally: check with true labels

# %% [markdown]
# ## Plot cycle data with labels

# %%
# Extract true outliers cycle index from benchmarking dataset
true_outlier_cycle_index = benchdb.get_true_outlier_cycle_index(
    df_selected_cell)
print(f"True outlier cycle index:")
print(true_outlier_cycle_index)

# Plot cell data with true anomalies
# If the true outlier cycle index is not known,
# cycling data will be plotted without labels
benchdb.plot_cycle_data(
    df_selected_cell_without_labels,
    true_outlier_cycle_index)

output_fig_filename = (
    "cycle_data_with_labels_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir.joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# True outlier cycle index:
# [  0.  40. 147. 148.]

# %% [markdown]
# ## Calculate bubble size ratio

# %%
# Calculate the bubble size ratio for plotting
df_bubble_size_dQ = bviz.calculate_bubble_size_ratio(
    df_variable=df_features_per_cell["max_diff_dQ"])

df_bubble_size_dV = bviz.calculate_bubble_size_ratio(
    df_variable=df_features_per_cell["max_diff_dV"])

bubble_size = (
    np.abs(df_bubble_size_dV)
    * np.abs(df_bubble_size_dQ))
# Out:
# Feature mean: 0.00641125672398844
# Feature max: 0.042899057000000074
# Feature min: 0.006194469999999952
# Feature std: 0.0019646872892444154
# **********************************************************************
# Feature mean: 0.04105323627167629
# Feature max: 2.612268400000005
# Feature min: 0.022684100000000207
# Feature std: 0.11397361246602544
# **********************************************************************

# %% [markdown]
# ## Plot the bubble chart and label the true outliers

# %%
# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=df_features_per_cell["log_max_diff_dQ"],
    yseries=df_features_per_cell["log_max_diff_dV"],
    bubble_size=bubble_size,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=true_outlier_cycle_index)

axplot.set_title(
    f"Cell {selected_cell_label}", fontsize=13)

axplot.set_xlabel(
     r"$\log(\Delta Q_{\mathrm{scaled,max,cyc}})$ [Ah]",
     fontsize = 12)

axplot.set_ylabel(
     r"$\log(\Delta V_{\mathrm{scaled,max,cyc}})$ [V]",
     fontsize = 12)

output_fig_filename = (
    "log_bubble_plot_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir.joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=200,
    bbox_inches="tight")

plt.show()
# Out:
# Potential anomalous cycle: 0.0
# x-position of the text: -5.053343441284631
# y-position of the text: 0.44734305691240445
# ----------------------------------------------------------------------
# Potential anomalous cycle: 40.0
# x-position of the text: -5.066424997988364
# y-position of the text: 0.9602189626435208
# ----------------------------------------------------------------------
# Potential anomalous cycle: 147.0
# x-position of the text: -3.1508950320267735
# y-position of the text: -3.5256965450993665
# ----------------------------------------------------------------------
# Potential anomalous cycle: 148.0
# x-position of the text: -3.1489054346417387
# y-position of the text: -3.6794044837514233
# ----------------------------------------------------------------------
