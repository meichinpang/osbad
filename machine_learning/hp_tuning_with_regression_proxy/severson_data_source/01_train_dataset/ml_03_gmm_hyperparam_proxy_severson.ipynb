# %% [markdown]
# # Import libraries

# %%
# %load_ext autoreload
# %autoreload 2

# Standard library
from pathlib import Path
import pprint

# Third-party libraries
import duckdb
import fireducks.pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import optuna
from matplotlib import rcParams

rcParams["text.usetex"] = True

# Custom osbad library for anomaly detection
import osbad.config as bconf
import osbad.hyperparam as hp
import osbad.modval as modval
import osbad.viz as bviz
from osbad.database import BenchDB
from osbad.model import ModelRunner

# %% [markdown]
# # Import dataset

# %%
# Define a global variable to save fig output
# The definition of PIPELINE_OUTPUT_DIR can be
# found in config.py
PIPELINE_OUTPUT_DIR = bconf.PIPELINE_OUTPUT_DIR

# Path to database directory
DB_DIR = bconf.DB_DIR

# Path to the DuckDB instance:
# "osbad/database/train_dataset_severson.db"
db_filepath = (
    DB_DIR.joinpath("train_dataset_severson.db"))

# %% [markdown]
# ## Get unique cell labels from training dataset

# %%
# Create a DuckDB connection
con = duckdb.connect(
    db_filepath,
    read_only=True)

# Load all training dataset from duckdb
df_duckdb = con.execute(
    "SELECT * FROM df_train_dataset_sv").fetchdf()

unique_cell_index_train = df_duckdb["cell_index"].unique()
print(unique_cell_index_train)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ['2017-05-12_5_4C-50per_3C_CH13' '2017-05-12_5_4C-50per_3C_CH14'
#  '2017-05-12_5_4C-60per_3C_CH15' '2017-05-12_5_4C-60per_3C_CH16'
#  '2017-05-12_5_4C-70per_3C_CH17' '2017-05-12_5_4C-70per_3C_CH18'
#  '2017-05-12_6C-40per_3C_CH25' '2017-05-12_6C-40per_3C_CH26'
#  '2017-05-12_6C-50per_3C_CH27' '2017-05-12_6C-50per_3C_CH28'
#  '2017-05-12_6C-60per_3C_CH29' '2017-05-12_6C-60per_3C_CH30'
#  '2017-05-12_7C-40per_3C_CH37' '2017-05-12_7C-40per_3C_CH38'
#  '2017-05-12_4C-80per_4C_CH5' '2017-05-12_4C-80per_4C_CH6'
#  '2017-05-12_4_4C-80per_4_4C_CH7' '2017-05-12_5_4C-80per_5_4C_CH11'
#  '2017-05-12_5_4C-80per_5_4C_CH12' '2017-05-12_3_6C-80per_3_6C_CH1'
#  '2017-05-12_3_6C-80per_3_6C_CH2' '2017-05-12_3_6C-80per_3_6C_CH3'
#  '2017-05-12_5_4C-40per_3_6C_CH19']

# %%
training_cell_count = len(unique_cell_index_train)
print(f"Training cell count: {training_cell_count}")
# Out:
# Training cell count: 23

# %% [markdown]
# ## Define selected_cell_label

# %%
# Get the cell-ID from cell_inventory
selected_cell_label = "2017-05-12_5_4C-70per_3C_CH17"

# Create a subfolder to store fig output
# corresponding to each cell-index
selected_cell_artifacts_dir = bconf.artifacts_output_dir(
    selected_cell_label)

# %% [markdown]
# # Load benchmarking dataset

# %%
# Import the BenchDB class
# Load only the dataset based on the selected cell
benchdb = BenchDB(
    db_filepath,
    selected_cell_label)

# load the benchmarking dataset
df_selected_cell = benchdb.load_benchmark_dataset(
    dataset_type="train")
# Out:
# Database is found in the given filepath.
# Loading benchmarking dataset now...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ****************************************************************************************************

# %% [markdown]
# ## Drop labels

# %%
if df_selected_cell is not None:

    filter_col = [
        "cell_index",
        "cycle_index",
        "discharge_capacity",
        "voltage"]

    # Drop true labels from the benchmarking dataset
    # and filter for selected columns only
    df_selected_cell_without_labels = benchdb.drop_labels(
        df_selected_cell,
        filter_col)

    # print a subset of the dataframe
    # for diagnostics running in terminals
    print(df_selected_cell_without_labels.head(10).to_markdown())
    print("*"*100)
# Out:
# |    | cell_index                    |   cycle_index |   discharge_capacity |   voltage |
# |---:|:------------------------------|--------------:|---------------------:|----------:|
# |  0 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          1.26512e-05 |   3.29189 |
# |  1 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00136774  |   3.28185 |
# |  2 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00292998  |   3.27788 |
# |  3 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00449361  |   3.27513 |
# |  4 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00449361  |   3.27513 |
# |  5 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00605927  |   3.27299 |
# |  6 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00762155  |   3.27124 |
# |  7 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0091859   |   3.2703  |
# |  8 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0107469   |   3.26875 |
# |  9 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0123127   |   3.26787 |
# ****************************************************************************************************

# %% [markdown]
# ## Plot cycle data without labels

# %%
# If the true outlier cycle index is not known,
# cycling data will be plotted without labels
benchdb.plot_cycle_data(
    df_selected_cell_without_labels)

output_fig_filename = (
    "cycle_data_without_labels_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Features transformation

# %% [markdown]
# ## Load the training features dataset

# %%
# Define the filepath to ``train_features_severson.db``
# osbad/database/train_features_severson.db
db_features_filepath = (
    DB_DIR.joinpath(
        "train_features_severson.db"))

# Load only the training features dataset
df_features_per_cell = benchdb.load_features_db(
    db_features_filepath,
    dataset_type="train")

unique_cycle_count = (
    df_features_per_cell["cycle_index"].unique())
# Out:
# Features database is found in the given filepath.
# Features database is loaded.
# ****************************************************************************************************

# %%
df_features_per_cell
# Out:
#      max_diff_dQ  log_max_diff_dQ  cycle_index  max_diff_dV  log_max_diff_dV  \
# 0       0.006388        -5.053343          0.0     1.564151         0.447343
# 1       0.006338        -5.061258          1.0     0.023727        -3.741163
# 2       0.006321        -5.063922          2.0     0.022684        -3.786091
# 3       0.006259        -5.073756          3.0     0.027899        -3.579172
# 4       0.006236        -5.077346          4.0     0.026408        -3.634081
# ..           ...              ...          ...          ...              ...
# 687     0.006236        -5.077391        687.0     0.046420        -3.070023
# 688     0.006281        -5.070178        688.0     0.051542        -2.965352
# 689     0.006243        -5.076238        689.0     0.047776        -3.041228
# 690     0.006316        -5.064619        690.0     0.046331        -3.071935
# 691     0.006402        -5.051123        691.0     0.047873        -3.039193
#
#                         cell_index
# 0    2017-05-12_5_4C-70per_3C_CH17
# 1    2017-05-12_5_4C-70per_3C_CH17
# 2    2017-05-12_5_4C-70per_3C_CH17
# 3    2017-05-12_5_4C-70per_3C_CH17
# 4    2017-05-12_5_4C-70per_3C_CH17
# ..                             ...
# 687  2017-05-12_5_4C-70per_3C_CH17
# 688  2017-05-12_5_4C-70per_3C_CH17
# 689  2017-05-12_5_4C-70per_3C_CH17
# 690  2017-05-12_5_4C-70per_3C_CH17
# 691  2017-05-12_5_4C-70per_3C_CH17
#
# [692 rows x 6 columns]

# %% [markdown]
# # Hyperparameter tuning

# %% [markdown]
# ## Create optuna study

# %%
hp_config_gmm = {
    "contamination": {"low": 0.0, "high": 0.5},
    "n_components": {"low": 1, "high": 6},
    "covariance_type": ["spherical", "diag", "tied", "full"],
    "init_param": ["kmeans","random"],
    "threshold": {"low": 0.0, "high": 1.0}
}

gmm_hp_config_filepath = (
    Path.cwd()
    .parents[3]
    .joinpath(
        "machine_learning",
        "hp_config_schema",
        "severson_hp_config",
        "gmm_hp_config.json"))

bconf.create_json_hp_config(
    gmm_hp_config_filepath,
    hp_dict=hp_config_gmm)

bconf.load_json_hp_config(
    gmm_hp_config_filepath)
# Out:
# {'contamination': {'low': 0.0, 'high': 0.5},
#  'n_components': {'low': 1, 'high': 6},
#  'covariance_type': ['spherical', 'diag', 'tied', 'full'],
#  'init_param': ['kmeans', 'random'],
#  'threshold': {'low': 0.0, 'high': 1.0}}

# %%
# Reload the hp module to refresh in-memory variables
# especially after updating parameters
from importlib import reload
reload(hp)

# Check if the schema in the script has been updated 
# based on the current constraints specified 
# from the notebook
print("Current hyperparameter config:")
print(hp._GMM_HP_CONFIG)
print("-"*70)

# Instantiate an optuna study for gmm model
sampler = optuna.samplers.TPESampler(seed=42)

selected_feature_cols = (
    "cycle_index",
    "log_max_diff_dQ",
    "log_max_diff_dV")

gmm_study = optuna.create_study(
    study_name="gmm_hyperparam",
    sampler=sampler,
    directions=["minimize","maximize"])

gmm_study.optimize(
    lambda trial: hp.objective(
        trial,
        model_id="gmm",
        df_feature_dataset=df_features_per_cell,
        selected_feature_cols=selected_feature_cols,
        #df_benchmark_dataset=df_selected_cell,
        selected_cell_label=selected_cell_label),
    n_trials=150)
# Out:
# [I 2025-10-13 13:42:51,510] A new study created in memory with name: gmm_hyperparam
# [I 2025-10-13 13:42:51,529] Trial 0 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 3, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.4330880728874676, 'threshold': 0.6011150117432088}.
# [I 2025-10-13 13:42:51,550] Trial 1 finished with values: [0.19898630510395884, 0.9869942196531792] and parameters: {'n_components': 5, 'covariance_type': 'diag', 'init_param': 'random', 'contamination': 0.15212112147976886, 'threshold': 0.5247564316322378}.
# [I 2025-10-13 13:42:51,563] Trial 2 finished with values: [0.17110010915352933, 0.8858381502890174] and parameters: {'n_components': 3, 'covariance_type': 'diag', 'init_param': 'random', 'contamination': 0.3925879806965068, 'threshold': 0.19967378215835974}.
# [I 2025-10-13 13:42:51,572] Trial 3 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'tied', 'init_param': 'random', 'contamination': 0.4828160165372797, 'threshold': 0.8083973481164611}.
# [I 2025-10-13 13:42:51,589] Trial 4 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 2, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.45466020103939103, 'threshold': 0.2587799816000169}.
# [I 2025-10-13 13:42:51,617] Trial 5 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'tied', 'init_param': 'kmeans', 'contamination': 0.46974947078209456, 'threshold': 0.8948273504276488}.
# [I 2025-10-13 13:42:51,645] Trial 6 finished with values: [0.19869877286603393, 0.9913294797687862] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.13567451588694796, 'threshold': 0.8287375091519293}.
# [I 2025-10-13 13:42:51,668] Trial 7 finished with values: [0.15651909945797302, 0.8526011560693642] and parameters: {'n_components': 3, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.3861223846483287, 'threshold': 0.1987156815341724}.
# [I 2025-10-13 13:42:51,678] Trial 8 finished with values: [0.631856965066327, 0.9985549132947977] and parameters: {'n_components': 1, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.05793452976256486, 'threshold': 0.8631034258755935}.
# [I 2025-10-13 13:42:51,692] Trial 9 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.44360637128816327, 'threshold': 0.4722149251619493}.
# Current hyperparameter config:
# {'contamination': {'low': 0.0, 'high': 0.5}, 'n_components': {'low': 1, 'high': 6}, 'covariance_type': ['spherical', 'diag', 'tied', 'full'], 'init_param': ['kmeans', 'random'], 'threshold': {'low': 0.0, 'high': 1.0}}
# ----------------------------------------------------------------------
# [I 2025-10-13 13:42:51,748] Trial 10 finished with values: [0.8655800934054974, 0.9942196531791907] and parameters: {'n_components': 6, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.24558855583452746, 'threshold': 0.6968852360928194}.
# [I 2025-10-13 13:42:51,790] Trial 11 finished with values: [0.16492047298042906, 0.8063583815028902] and parameters: {'n_components': 2, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.31344182245328395, 'threshold': 0.007834138444767269}.
# [I 2025-10-13 13:42:51,830] Trial 12 finished with values: [0.1877158476145669, 0.953757225433526] and parameters: {'n_components': 5, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.19905558861290246, 'threshold': 0.3425159937377566}.
# [I 2025-10-13 13:42:51,873] Trial 13 finished with values: [0.16552611066232634, 0.8020231213872833] and parameters: {'n_components': 2, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.006145149313477982, 'threshold': 0.007589228414826565}.
# [I 2025-10-13 13:42:51,903] Trial 14 finished with values: [0.631856965066327, 0.9985549132947977] and parameters: {'n_components': 3, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.3384090290478076, 'threshold': 0.9799550743894989}.
# [I 2025-10-13 13:42:51,933] Trial 15 finished with values: [0.13407193064308995, 0.7369942196531792] and parameters: {'n_components': 5, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.12193748043178404, 'threshold': 0.15578379319318553}.
# [I 2025-10-13 13:42:51,953] Trial 16 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 1, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.33170321430599126, 'threshold': 0.38076625659147184}.
# [I 2025-10-13 13:42:52,032] Trial 17 finished with values: [1.0012866211341545, 0.9985549132947977] and parameters: {'n_components': 6, 'covariance_type': 'tied', 'init_param': 'kmeans', 'contamination': 0.2608239376893775, 'threshold': 0.6719642191335772}.
# [I 2025-10-13 13:42:52,080] Trial 18 finished with values: [0.8693179799693111, 0.9869942196531792] and parameters: {'n_components': 3, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.10757889456072299, 'threshold': 0.7411531911799476}.
# [I 2025-10-13 13:42:52,120] Trial 19 finished with values: [0.1015707822125407, 0.5260115606936416] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.1941353372836316, 'threshold': 0.10546323002943592}.
# [I 2025-10-13 13:42:52,152] Trial 20 finished with values: [0.1836966293628392, 0.9710982658959537] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.10078609316678813, 'threshold': 0.44499878390783937}.
# [I 2025-10-13 13:42:52,195] Trial 21 finished with values: [0.1434860619132035, 0.791907514450867] and parameters: {'n_components': 5, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.38187369745742644, 'threshold': 0.18303300285044038}.
# [I 2025-10-13 13:42:52,229] Trial 22 finished with values: [0.17448364901360203, 0.9566473988439307] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.04893242440337606, 'threshold': 0.3395655368010748}.
# [I 2025-10-13 13:42:52,279] Trial 23 finished with values: [0.16658758302493173, 0.9277456647398844] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.01264869331652698, 'threshold': 0.3146336337587906}.
# [I 2025-10-13 13:42:52,314] Trial 24 finished with values: [0.1649639766397106, 0.8901734104046243] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.01382318086858598, 'threshold': 0.2849421862035556}.
# [I 2025-10-13 13:42:52,355] Trial 25 finished with values: [0.13606410747181402, 0.6820809248554913] and parameters: {'n_components': 6, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.0628722362906964, 'threshold': 0.0901740529474277}.
# [I 2025-10-13 13:42:52,399] Trial 26 finished with values: [1.0012866211341545, 0.9985549132947977] and parameters: {'n_components': 6, 'covariance_type': 'tied', 'init_param': 'kmeans', 'contamination': 0.1963069919843618, 'threshold': 0.5723967276344128}.
# [I 2025-10-13 13:42:52,435] Trial 27 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.03320481103046957, 'threshold': 0.39847829565329557}.
# [I 2025-10-13 13:42:52,469] Trial 28 finished with values: [0.17791794297531188, 0.953757225433526] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.03976331520856748, 'threshold': 0.4094702078000062}.
# [I 2025-10-13 13:42:52,506] Trial 29 finished with values: [0.18129410277970423, 0.9682080924855492] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.07443173752818999, 'threshold': 0.2899889999736095}.
# [I 2025-10-13 13:42:52,547] Trial 30 finished with values: [0.18810615616857274, 0.9754335260115607] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.00013117505355334826, 'threshold': 0.5311722628160155}.
# [I 2025-10-13 13:42:52,623] Trial 31 finished with values: [0.1441199331015438, 0.7803468208092486] and parameters: {'n_components': 5, 'covariance_type': 'full', 'init_param': 'kmeans', 'contamination': 0.09425729153651541, 'threshold': 0.1738988588390154}.
# [I 2025-10-13 13:42:52,680] Trial 32 finished with values: [0.13459439478238897, 0.7008670520231214] and parameters: {'n_components': 5, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.1483900816759382, 'threshold': 0.12893769886120732}.
# [I 2025-10-13 13:42:52,717] Trial 33 finished with values: [0.16599102808946556, 0.9450867052023122] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.03129961791316717, 'threshold': 0.272861292555656}.
# [I 2025-10-13 13:42:52,757] Trial 34 finished with values: [0.33664418148209285, 0.9913294797687862] and parameters: {'n_components': 5, 'covariance_type': 'tied', 'init_param': 'kmeans', 'contamination': 0.4088174443664646, 'threshold': 0.22712729139813276}.
# [I 2025-10-13 13:42:52,798] Trial 35 finished with values: [0.13791209591780923, 0.7861271676300579] and parameters: {'n_components': 4, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.12614316297733338, 'threshold': 0.16094236135560103}.
# [I 2025-10-13 13:42:52,849] Trial 36 finished with values: [0.11479958657937245, 0.5867052023121387] and parameters: {'n_components': 4, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.17920836574747878, 'threshold': 0.10842482134159176}.
# [I 2025-10-13 13:42:52,890] Trial 37 pruned.
# [I 2025-10-13 13:42:52,931] Trial 38 finished with values: [0.1624008947815455, 0.8757225433526011] and parameters: {'n_components': 4, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.24187270614318424, 'threshold': 0.22732461163924236}.
# [I 2025-10-13 13:42:52,978] Trial 39 pruned.
# [I 2025-10-13 13:42:53,010] Trial 40 finished with values: [0.18402239663641556, 0.9277456647398844] and parameters: {'n_components': 3, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.08343276365622991, 'threshold': 0.2500001417592955}.
# [I 2025-10-13 13:42:53,049] Trial 41 finished with values: [0.19423582204661624, 0.9754335260115607] and parameters: {'n_components': 4, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.03723916498996337, 'threshold': 0.3990768087515905}.
# [I 2025-10-13 13:42:53,100] Trial 42 finished with values: [0.1991195175727703, 0.9841040462427746] and parameters: {'n_components': 4, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.11985087377899496, 'threshold': 0.4925286306100357}.
# [I 2025-10-13 13:42:53,134] Trial 43 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.03027402772579577, 'threshold': 0.37319198540166587}.
# [I 2025-10-13 13:42:53,168] Trial 44 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 2, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.07092279672587018, 'threshold': 0.2655272794027519}.
# [I 2025-10-13 13:42:53,194] Trial 45 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 3, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.13913652108313188, 'threshold': 0.43746721940436845}.
# [I 2025-10-13 13:42:53,275] Trial 46 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'tied', 'init_param': 'kmeans', 'contamination': 0.031153472059930187, 'threshold': 0.14478515155606703}.
# [I 2025-10-13 13:42:53,402] Trial 47 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.21663231589830523, 'threshold': 0.5266603249395979}.
# [I 2025-10-13 13:42:53,487] Trial 48 finished with values: [0.18835418149890495, 0.9566473988439307] and parameters: {'n_components': 4, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.2925804190761892, 'threshold': 0.34322258339674355}.
# [I 2025-10-13 13:42:53,509] Trial 49 finished with values: [0.15936494013979838, 0.9335260115606936] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.12373913882284195, 'threshold': 0.21926988828443378}.
# [I 2025-10-13 13:42:53,528] Trial 50 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 1, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.4973710055956628, 'threshold': 0.6312734618700357}.
# [I 2025-10-13 13:42:53,561] Trial 51 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.1767317546510486, 'threshold': 0.12417640831521412}.
# [I 2025-10-13 13:42:53,594] Trial 52 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 3, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.13028201731113698, 'threshold': 0.19872722167220724}.
# [I 2025-10-13 13:42:53,617] Trial 53 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.2193528301904275, 'threshold': 0.9495786432186333}.
# [I 2025-10-13 13:42:53,643] Trial 54 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'tied', 'init_param': 'kmeans', 'contamination': 0.10517802319848771, 'threshold': 0.09761183293909212}.
# [I 2025-10-13 13:42:53,672] Trial 55 finished with values: [0.19869877286603393, 0.9913294797687862] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.1587939538394294, 'threshold': 0.7674152324822949}.
# [I 2025-10-13 13:42:53,706] Trial 56 finished with values: [0.18940068120676667, 0.9783236994219653] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.45484234218275604, 'threshold': 0.46182951205013756}.
# [I 2025-10-13 13:42:53,743] Trial 57 finished with values: [0.15258776139098934, 0.9176300578034682] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.19502256509373928, 'threshold': 0.22948511490034157}.
# [I 2025-10-13 13:42:53,775] Trial 58 finished with values: [0.18654774110558958, 0.9450867052023122] and parameters: {'n_components': 6, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.052906923516914665, 'threshold': 0.33044151992079257}.
# [I 2025-10-13 13:42:53,808] Trial 59 finished with values: [0.18994545121660467, 0.9450867052023122] and parameters: {'n_components': 3, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.05307179391342835, 'threshold': 0.3233808838875914}.
# [I 2025-10-13 13:42:53,840] Trial 60 finished with values: [0.1883029601366532, 0.9566473988439307] and parameters: {'n_components': 5, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.2948231138455218, 'threshold': 0.3527120820315889}.
# [I 2025-10-13 13:42:53,864] Trial 61 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 1, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.21742128130866956, 'threshold': 0.41283538801154496}.
# [I 2025-10-13 13:42:53,897] Trial 62 finished with values: [0.19100723313456566, 0.9812138728323699] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.2688321710359035, 'threshold': 0.5675192396762088}.
# [I 2025-10-13 13:42:53,917] Trial 63 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 4, 'covariance_type': 'tied', 'init_param': 'random', 'contamination': 0.08962461255769825, 'threshold': 0.15686240931860868}.
# [I 2025-10-13 13:42:53,951] Trial 64 finished with values: [0.17552029017138726, 0.9523121387283237] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.3482164409841504, 'threshold': 0.299816158624941}.
# [I 2025-10-13 13:42:53,976] Trial 65 finished with values: [0.19869877286603393, 0.9913294797687862] and parameters: {'n_components': 3, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.020458312313112608, 'threshold': 0.862712132032284}.
# [I 2025-10-13 13:42:54,003] Trial 66 finished with values: [0.17780389090226156, 0.9595375722543352] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.17886875946271494, 'threshold': 0.3706459814000703}.
# [I 2025-10-13 13:42:54,031] Trial 67 finished with values: [0.18488224977090262, 0.9739884393063584] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.048514320196298796, 'threshold': 0.4938722433131797}.
# [I 2025-10-13 13:42:54,064] Trial 68 finished with values: [0.1951841658114846, 0.9797687861271677] and parameters: {'n_components': 5, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.07506788109191233, 'threshold': 0.43724238189685827}.
# [I 2025-10-13 13:42:54,084] Trial 69 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 6, 'covariance_type': 'tied', 'init_param': 'random', 'contamination': 0.22965834240508196, 'threshold': 0.04720075701791318}.
# [I 2025-10-13 13:42:54,110] Trial 70 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 2, 'covariance_type': 'diag', 'init_param': 'random', 'contamination': 0.1995472545816042, 'threshold': 0.25967784654805254}.
# [I 2025-10-13 13:42:54,142] Trial 71 finished with values: [0.1486996104376556, 0.9046242774566474] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.00015383409105654278, 'threshold': 0.20182202615326927}.
# [I 2025-10-13 13:42:54,172] Trial 72 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.0025843736484741676, 'threshold': 0.6634177333066056}.
# [I 2025-10-13 13:42:54,199] Trial 73 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.11323795882594709, 'threshold': 0.5616787381338313}.
# [I 2025-10-13 13:42:54,225] Trial 74 finished with values: [0.07369625106935937, 0.5187861271676301] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.01400536110454802, 'threshold': 0.1668105130069635}.
# [I 2025-10-13 13:42:54,252] Trial 75 pruned.
# [I 2025-10-13 13:42:54,280] Trial 76 finished with values: [0.11262126593197967, 0.6372832369942196] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.02400622649641007, 'threshold': 0.1966855056824979}.
# [I 2025-10-13 13:42:54,304] Trial 77 finished with values: [0.099894581871009, 0.5708092485549133] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.043459791067588516, 'threshold': 0.1789421065273085}.
# [I 2025-10-13 13:42:54,331] Trial 78 finished with values: [0.09761109423209079, 0.565028901734104] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.029217151106300077, 'threshold': 0.1754738918912777}.
# [I 2025-10-13 13:42:54,356] Trial 79 finished with values: [0.16489559559642364, 0.9002890173410405] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.022792146572932596, 'threshold': 0.2934424447876369}.
# [I 2025-10-13 13:42:54,380] Trial 80 finished with values: [0.15869517645378403, 0.8641618497109826] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.4216365873811323, 'threshold': 0.26371305875013396}.
# [I 2025-10-13 13:42:54,408] Trial 81 finished with values: [0.12330318872069741, 0.6734104046242775] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.06613876138860311, 'threshold': 0.20686800608337888}.
# [I 2025-10-13 13:42:54,433] Trial 82 finished with values: [0.11280192041693603, 0.6430635838150289] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.010462378157576922, 'threshold': 0.19881233842991358}.
# [I 2025-10-13 13:42:54,458] Trial 83 finished with values: [0.07426164142810635, 0.5101156069364162] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.00174554836537337, 'threshold': 0.1598407704290262}.
# [I 2025-10-13 13:42:54,479] Trial 84 finished with values: [0.17543644393485155, 0.953757225433526] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.0372097991446667, 'threshold': 0.03253707029661035}.
# [I 2025-10-13 13:42:54,505] Trial 85 pruned.
# [I 2025-10-13 13:42:54,538] Trial 86 finished with values: [0.1699075316398488, 0.8771676300578035] and parameters: {'n_components': 5, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.05238510364967893, 'threshold': 0.2378570837250879}.
# [I 2025-10-13 13:42:54,558] Trial 87 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.03225505061737517, 'threshold': 0.14367244400877344}.
# [I 2025-10-13 13:42:54,579] Trial 88 finished with values: [0.1028706532510128, 0.5838150289017341] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.06017111685329718, 'threshold': 0.18309319919713352}.
# [I 2025-10-13 13:42:54,613] Trial 89 finished with values: [0.17530583645179593, 0.9234104046242775] and parameters: {'n_components': 4, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.08080673630596619, 'threshold': 0.2722753071053425}.
# [I 2025-10-13 13:42:54,638] Trial 90 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.04215500104229006, 'threshold': 0.49336265289795944}.
# [I 2025-10-13 13:42:54,660] Trial 91 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.06203257822051358, 'threshold': 0.2038905472399711}.
# [I 2025-10-13 13:42:54,684] Trial 92 finished with values: [0.13167122548627536, 0.703757225433526] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.008622690647005032, 'threshold': 0.2144781887516436}.
# [I 2025-10-13 13:42:54,706] Trial 93 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.02750960887469926, 'threshold': 0.597222050697596}.
# [I 2025-10-13 13:42:54,726] Trial 94 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 5, 'covariance_type': 'tied', 'init_param': 'random', 'contamination': 0.01818110520775562, 'threshold': 0.3073531952245891}.
# [I 2025-10-13 13:42:54,750] Trial 95 finished with values: [0.17552029017138726, 0.9523121387283237] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.07033707335609589, 'threshold': 0.39365342388769414}.
# [I 2025-10-13 13:42:54,777] Trial 96 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.0002939979342835679, 'threshold': 0.08281408011827951}.
# [I 2025-10-13 13:42:54,804] Trial 97 finished with values: [0.1267184733523625, 0.7572254335260116] and parameters: {'n_components': 3, 'covariance_type': 'diag', 'init_param': 'random', 'contamination': 0.041945936351195555, 'threshold': 0.10970334222998289}.
# [I 2025-10-13 13:42:54,823] Trial 98 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 2, 'covariance_type': 'diag', 'init_param': 'random', 'contamination': 0.03851518518162078, 'threshold': 0.12580618359864887}.
# [I 2025-10-13 13:42:54,846] Trial 99 finished with values: [0.12642519367699023, 0.7528901734104047] and parameters: {'n_components': 3, 'covariance_type': 'diag', 'init_param': 'random', 'contamination': 0.04827505571038156, 'threshold': 0.10470176815929312}.
# [I 2025-10-13 13:42:54,871] Trial 100 finished with values: [0.15661830441047953, 0.9176300578034682] and parameters: {'n_components': 3, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.015082454399628686, 'threshold': 0.2444424806738269}.
# [I 2025-10-13 13:42:54,891] Trial 101 finished with values: [0.14005356048021134, 0.7630057803468208] and parameters: {'n_components': 5, 'covariance_type': 'diag', 'init_param': 'random', 'contamination': 0.09272522382131218, 'threshold': 0.1606463018790824}.
# [I 2025-10-13 13:42:54,920] Trial 102 finished with values: [0.8655800934054974, 0.9942196531791907] and parameters: {'n_components': 5, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.010823728159320423, 'threshold': 0.7850353799887348}.
# [I 2025-10-13 13:42:54,942] Trial 103 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 5, 'covariance_type': 'tied', 'init_param': 'random', 'contamination': 0.027248038921201808, 'threshold': 0.510714457428617}.
# [I 2025-10-13 13:42:54,965] Trial 104 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 1, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.046368167857540214, 'threshold': 0.47473097170501394}.
# [I 2025-10-13 13:42:54,991] Trial 105 pruned.
# [I 2025-10-13 13:42:55,015] Trial 106 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.055352184470663764, 'threshold': 0.42770484678635656}.
# [I 2025-10-13 13:42:55,052] Trial 107 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.360731025353652, 'threshold': 0.7072322604507563}.
# [I 2025-10-13 13:42:55,071] Trial 108 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 2, 'covariance_type': 'diag', 'init_param': 'random', 'contamination': 0.4683968009738778, 'threshold': 0.278693795528945}.
# [I 2025-10-13 13:42:55,095] Trial 109 finished with values: [0.15216288699634442, 0.9176300578034682] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.021144775066119365, 'threshold': 0.1754953726959579}.
# [I 2025-10-13 13:42:55,118] Trial 110 finished with values: [0.8649904037534204, 0.9942196531791907] and parameters: {'n_components': 3, 'covariance_type': 'full', 'init_param': 'random', 'contamination': 0.04016017798941495, 'threshold': 0.9480195411680612}.
# [I 2025-10-13 13:42:55,138] Trial 111 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 1, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.06058155732600802, 'threshold': 0.5435194587655927}.
# [I 2025-10-13 13:42:55,163] Trial 112 finished with values: [0.13691759272903894, 0.6994219653179191] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.011248154494998275, 'threshold': 0.14104187990185832}.
# [I 2025-10-13 13:42:55,196] Trial 113 finished with values: [0.18933819964332563, 0.9653179190751445] and parameters: {'n_components': 5, 'covariance_type': 'diag', 'init_param': 'kmeans', 'contamination': 0.3951430989761532, 'threshold': 0.362535645135931}.
# [I 2025-10-13 13:42:55,217] Trial 114 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 3, 'covariance_type': 'tied', 'init_param': 'random', 'contamination': 0.07764260978968474, 'threshold': 0.1847727309653473}.
# [I 2025-10-13 13:42:55,241] Trial 115 finished with values: [0.13840108398273857, 0.7355491329479769] and parameters: {'n_components': 6, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.060006197128139614, 'threshold': 0.22396104595746377}.
# [I 2025-10-13 13:42:55,267] Trial 116 finished with values: [0.09668251006051053, 0.7369942196531792] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.029060841912921957, 'threshold': 0.10978974909811123}.
# [I 2025-10-13 13:42:55,292] Trial 117 finished with values: [0.19990369723656812, 0.976878612716763] and parameters: {'n_components': 2, 'covariance_type': 'full', 'init_param': 'kmeans', 'contamination': 0.26678129531842876, 'threshold': 0.041931370651701605}.
# [I 2025-10-13 13:42:55,316] Trial 118 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 1, 'covariance_type': 'tied', 'init_param': 'kmeans', 'contamination': 0.30048052119838864, 'threshold': 0.06569429366097043}.
# [I 2025-10-13 13:42:55,353] Trial 119 finished with values: [0.0857795578955147, 0.6950867052023122] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.44849220578104154, 'threshold': 0.08799597332241248}.
# [I 2025-10-13 13:42:55,377] Trial 120 pruned.
# [I 2025-10-13 13:42:55,406] Trial 121 finished with values: [0.09668251006051053, 0.7369942196531792] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.49679777585918905, 'threshold': 0.10905828790193733}.
# [I 2025-10-13 13:42:55,431] Trial 122 finished with values: [0.18940068120676667, 0.9783236994219653] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.3196394522701448, 'threshold': 0.46429291663396544}.
# [I 2025-10-13 13:42:55,457] Trial 123 finished with values: [0.08045673800888782, 0.6719653179190751] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.36606377168919313, 'threshold': 0.07787368613521467}.
# [I 2025-10-13 13:42:55,483] Trial 124 finished with values: [0.18023891246252066, 0.9609826589595376] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.3706971599813089, 'threshold': 0.40676501071776955}.
# [I 2025-10-13 13:42:55,513] Trial 125 finished with values: [0.16867201628855497, 0.9378612716763006] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.4064207142803839, 'threshold': 0.3321478204596368}.
# [I 2025-10-13 13:42:55,543] Trial 126 finished with values: [0.17829337616264565, 0.9566473988439307] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.2840788174090527, 'threshold': 0.3890451543854814}.
# [I 2025-10-13 13:42:55,570] Trial 127 finished with values: [0.08697798846625628, 0.7008670520231214] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.34484281437343445, 'threshold': 0.09060590305862332}.
# [I 2025-10-13 13:42:55,598] Trial 128 finished with values: [0.33733236991965365, 0.9971098265895953] and parameters: {'n_components': 1, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.32773944828560286, 'threshold': 0.4231906618615908}.
# [I 2025-10-13 13:42:55,626] Trial 129 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.25277296216133255, 'threshold': 0.8830167463792571}.
# [I 2025-10-13 13:42:55,658] Trial 130 finished with values: [0.1875823339719301, 0.9739884393063584] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.3770617792301543, 'threshold': 0.44530808924484083}.
# [I 2025-10-13 13:42:55,700] Trial 131 pruned.
# [I 2025-10-13 13:42:55,731] Trial 132 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.02381278380627417, 'threshold': 0.6219734081076492}.
# [I 2025-10-13 13:42:55,771] Trial 133 finished with values: [0.13716746974231825, 0.8367052023121387] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.04729425227357851, 'threshold': 0.11416031952282996}.
# [I 2025-10-13 13:42:55,798] Trial 134 pruned.
# [I 2025-10-13 13:42:55,830] Trial 135 finished with values: [0.13912275229333468, 0.8482658959537572] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.41806741399406, 'threshold': 0.11790044522073387}.
# [I 2025-10-13 13:42:55,861] Trial 136 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.41290309338942877, 'threshold': 0.35483338700929573}.
# [I 2025-10-13 13:42:55,888] Trial 137 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 2, 'covariance_type': 'tied', 'init_param': 'kmeans', 'contamination': 0.4722273530560557, 'threshold': 0.8418360164851941}.
# [I 2025-10-13 13:42:55,915] Trial 138 finished with values: [0.13478533729565673, 0.7947976878612717] and parameters: {'n_components': 5, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.3899808472658289, 'threshold': 0.09696061312796875}.
# [I 2025-10-13 13:42:55,948] Trial 139 finished with values: [0.0637617285794926, 0.5953757225433526] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.3650991841106138, 'threshold': 0.05665471610262121}.
# [I 2025-10-13 13:42:55,978] Trial 140 finished with values: [0.06061609313898687, 0.5794797687861272] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.3432873248231647, 'threshold': 0.05422817062262719}.
# [I 2025-10-13 13:42:56,010] Trial 141 finished with values: [0.059142808415001906, 0.5722543352601156] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.14251445706446844, 'threshold': 0.05329764140303448}.
# [I 2025-10-13 13:42:56,047] Trial 142 finished with values: [0.19364680516710736, 0.9855491329479769] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.3587106796126783, 'threshold': 0.5162909215224596}.
# [I 2025-10-13 13:42:56,072] Trial 143 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 3, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.04006182928347365, 'threshold': 0.3771719156061077}.
# [I 2025-10-13 13:42:56,097] Trial 144 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 1, 'covariance_type': 'full', 'init_param': 'kmeans', 'contamination': 0.4302679937952194, 'threshold': 0.48657958786196825}.
# [I 2025-10-13 13:42:56,122] Trial 145 finished with values: [0.8636856621637496, 0.9971098265895953] and parameters: {'n_components': 3, 'covariance_type': 'spherical', 'init_param': 'kmeans', 'contamination': 0.14699527809550056, 'threshold': 0.45079794773359627}.
# [I 2025-10-13 13:42:56,153] Trial 146 finished with values: [0.200664623866367, 0.9942196531791907] and parameters: {'n_components': 2, 'covariance_type': 'tied', 'init_param': 'kmeans', 'contamination': 0.04773485601971561, 'threshold': 0.3137239372687666}.
# [I 2025-10-13 13:42:56,177] Trial 147 finished with values: [0.10134246220537589, 0.7528901734104047] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.022397427915791367, 'threshold': 0.11542303346257629}.
# [I 2025-10-13 13:42:56,210] Trial 148 finished with values: [0.19869877286603393, 0.9913294797687862] and parameters: {'n_components': 2, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.1650461613511811, 'threshold': 0.5903597890662927}.
# [I 2025-10-13 13:42:56,251] Trial 149 finished with values: [0.19462783279537613, 0.9869942196531792] and parameters: {'n_components': 4, 'covariance_type': 'spherical', 'init_param': 'random', 'contamination': 0.1031481752693546, 'threshold': 0.7304717375854555}.

# %% [markdown]
# ## Aggregate best trials

# %%
schema_gmm = {
    "contamination": "median",
    "n_components": "median_int",
    "covariance_type": "mode",
    "init_param": "mode",
    "threshold": "median",
}

trade_off_trials_list = hp.trade_off_trials_detection(
    gmm_study, 
    window_size=7)

df_gmm_hyperparam = hp.aggregate_best_trials(
    trade_off_trials_list,
    cell_label=selected_cell_label,
    model_id="gmm",
    schema=schema_gmm)

df_gmm_hyperparam
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ml_model</th>
#       <th>cell_index</th>
#       <th>contamination</th>
#       <th>n_components</th>
#       <th>covariance_type</th>
#       <th>init_param</th>
#       <th>threshold</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gmm</td>
#       <td>2017-05-12_5_4C-70per_3C_CH17</td>
#       <td>0.062689</td>
#       <td>4</td>
#       <td>tied</td>
#       <td>kmeans</td>
#       <td>0.310539</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Plot pareto front

# %%
hp.plot_proxy_pareto_front(
    gmm_study,
    trade_off_trials_list,
    selected_cell_label,
    fig_title="Gaussian Mixture Models (GMM) Pareto Front")

plt.show()
# Out:
# /home/basf/nasbattds/osbad/src/osbad/hyperparam.py:1027: ExperimentalWarning: optuna.visualization.matplotlib._pareto_front.plot_pareto_front is experimental (supported from v2.8.0). The interface can change in the future.
#   axplot = optuna.visualization.matplotlib.plot_pareto_front(

# %% [markdown]
# ## Export current hyperparameters to CSV

# %%
# Export current hyperparameters to CSV
hyperparam_filepath =  Path.cwd().joinpath(
    "ml_03_gmm_hyperparam_proxy_severson.csv")

hp.export_current_hyperparam(
    df_gmm_hyperparam,
    selected_cell_label,
    export_csv_filepath=hyperparam_filepath,
    if_exists="replace")
# Out:
# Have the hyperparam for 2017-05-12_5_4C-70per_3C_CH17 been evaluated?
# True
# **********************************************************************
# Replacing existing rows for 2017-05-12_5_4C-70per_3C_CH17.
# Hyperparameters for 2017-05-12_5_4C-70per_3C_CH17 have been replaced in the CSV file.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ml_model</th>
#       <th>cell_index</th>
#       <th>contamination</th>
#       <th>n_components</th>
#       <th>covariance_type</th>
#       <th>init_param</th>
#       <th>threshold</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gmm</td>
#       <td>2017-05-12_5_4C-70per_3C_CH17</td>
#       <td>0.062689</td>
#       <td>4</td>
#       <td>tied</td>
#       <td>kmeans</td>
#       <td>0.310539</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Train model with best trial parameters

# %% [markdown]
# ## Load best trial parameters from CSV output

# %%
# Test reading from exported metrics
df_hyperparam_from_csv = pd.read_csv(hyperparam_filepath)

df_param_per_cell = df_hyperparam_from_csv[
    df_hyperparam_from_csv["cell_index"] == selected_cell_label]
df_param_per_cell
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ml_model</th>
#       <th>cell_index</th>
#       <th>contamination</th>
#       <th>n_components</th>
#       <th>covariance_type</th>
#       <th>init_param</th>
#       <th>threshold</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gmm</td>
#       <td>2017-05-12_5_4C-70per_3C_CH17</td>
#       <td>0.062689</td>
#       <td>4</td>
#       <td>tied</td>
#       <td>kmeans</td>
#       <td>0.310539</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Create a dict for best trial parameters

# %%
param_dict = df_param_per_cell.iloc[0].to_dict()
pprint.pp(param_dict)
# Out:
# {'ml_model': 'gmm',
#  'cell_index': '2017-05-12_5_4C-70per_3C_CH17',
#  'contamination': 0.06268873290470017,
#  'n_components': 4,
#  'covariance_type': 'tied',
#  'init_param': 'kmeans',
#  'threshold': 0.31053856624667786}

# %% [markdown]
# ## Run the model with best trial parameters

# %%
cfg = hp.MODEL_CONFIG["gmm"]

selected_feature_cols = (
    "log_max_diff_dQ",
    "log_max_diff_dV")

runner = ModelRunner(
    cell_label=selected_cell_label,
    df_input_features=df_features_per_cell,
    selected_feature_cols=selected_feature_cols
)

Xdata = runner.create_model_x_input()

model = cfg.model_param(param_dict)
print(model)
model.fit(Xdata)
proba = model.predict_proba(Xdata)

pred_outlier_indices, pred_outlier_score = runner.pred_outlier_indices_from_proba(
    proba=proba,
    threshold=param_dict["threshold"],
    outlier_col=cfg.proba_col
)

pred_outlier_indices, pred_outlier_score
# Out:
# GMM(contamination=0.06268873290470017, covariance_type='tied',
#   init_params='kmeans', max_iter=100, means_init=None, n_components=4,
#   n_init=1, precisions_init=None, random_state=42, reg_covar=1e-06,
#   tol=0.001, warm_start=False, weights_init=None)
# (array([147, 148]), array([0.99944719, 1.        ]))

# %% [markdown]
# ## Get df_outliers_pred

# %%
df_outliers_pred = (df_features_per_cell[
    df_features_per_cell["cycle_index"]
    .isin(pred_outlier_indices)].copy())

df_outliers_pred["outlier_prob"] = pred_outlier_score
df_outliers_pred
# Out:
#      max_diff_dQ  log_max_diff_dQ  cycle_index  max_diff_dV  log_max_diff_dV  \
# 147     0.042814        -3.150895        147.0     0.029431        -3.525697
# 148     0.042899        -3.148905        148.0     0.025238        -3.679404
#
#                         cell_index  outlier_prob
# 147  2017-05-12_5_4C-70per_3C_CH17      0.999447
# 148  2017-05-12_5_4C-70per_3C_CH17      1.000000

# %% [markdown]
# ## Predict anomaly score map

# %%
axplot = runner.predict_anomaly_score_map(
    selected_model=model,
    model_name="Gaussian Mixture Models (GMM)",
    xoutliers=df_outliers_pred["log_max_diff_dQ"],
    youtliers=df_outliers_pred["log_max_diff_dV"],
    pred_outliers_index=pred_outlier_indices,
    threshold=param_dict["threshold"]
)

axplot.set_xlabel(
    r"$\log(\Delta Q_\textrm{scaled,max,cyc)}\;\textrm{[Ah]}$",
    fontsize=12)
axplot.set_ylabel(
    r"$\log(\Delta V_\textrm{scaled,max,cyc})\;\textrm{[V]}$",
    fontsize=12)

output_fig_filename = (
    "gmm_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Model performance evaluation

# %%
df_eval_outlier = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=pred_outlier_indices)

# %% [markdown]
# ## Confusion matrix

# %%
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier["true_outlier"],
    y_pred=df_eval_outlier["pred_outlier"])

axplot.set_title(
    "Gaussian Mixture Models (GMM)",
    fontsize=16)

output_fig_filename = (
    "conf_matrix_gmm_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Evaluate model performance

# %%
df_current_eval_metrics = modval.eval_model_performance(
    model_name="gmm",
    selected_cell_label=selected_cell_label,
    df_eval_outliers=df_eval_outlier)

df_current_eval_metrics
# Out:
# Accuracy: 0.9971098265895953
# Precision: 1.0
# Recall: 0.5
# F1-score: 0.6666666666666666
# MCC-score: 0.7060812450686402
# ****************************************************************************************************
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ml_model</th>
#       <th>cell_index</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1_score</th>
#       <th>mcc_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gmm</td>
#       <td>2017-05-12_5_4C-70per_3C_CH17</td>
#       <td>0.99711</td>
#       <td>1.0</td>
#       <td>0.5</td>
#       <td>0.666667</td>
#       <td>0.706081</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Export model performance metrics to CSV output

# %%
# Export current metrics to CSV
hyperparam_eval_filepath =  Path.cwd().joinpath(
    "eval_metrics_hp_single_cell_severson.csv")

hp.export_current_model_metrics(
    model_name="gmm",
    selected_cell_label=selected_cell_label,
    df_current_eval_metrics=df_current_eval_metrics,
    export_csv_filepath=hyperparam_eval_filepath,
    if_exists="replace")
# Out:
# Have the metrics for gmm on cell 2017-05-12_5_4C-70per_3C_CH17 been evaluated before?
# True
# ----------------------------------------------------------------------
# Replacing existing row for gmm, 2017-05-12_5_4C-70per_3C_CH17.
# Metrics for gmm, 2017-05-12_5_4C-70per_3C_CH17 have been replaced in the CSV file.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ml_model</th>
#       <th>cell_index</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1_score</th>
#       <th>mcc_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>iforest</td>
#       <td>2017-05-12_5_4C-70per_3C_CH17</td>
#       <td>1.00000</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>knn</td>
#       <td>2017-05-12_5_4C-70per_3C_CH17</td>
#       <td>1.00000</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>gmm</td>
#       <td>2017-05-12_5_4C-70per_3C_CH17</td>
#       <td>0.99711</td>
#       <td>1.0</td>
#       <td>0.5</td>
#       <td>0.666667</td>
#       <td>0.706081</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Finally: check with true labels

# %% [markdown]
# ## Plot cycle data with labels

# %%
# Extract true outliers cycle index from benchmarking dataset
true_outlier_cycle_index = benchdb.get_true_outlier_cycle_index(
    df_selected_cell)
print(f"True outlier cycle index:")
print(true_outlier_cycle_index)

# Plot cell data with true anomalies
# If the true outlier cycle index is not known,
# cycling data will be plotted without labels
benchdb.plot_cycle_data(
    df_selected_cell_without_labels,
    true_outlier_cycle_index)

output_fig_filename = (
    "cycle_data_with_labels_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir.joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# True outlier cycle index:
# [  0.  40. 147. 148.]

# %% [markdown]
# ## Calculate bubble size ratio

# %%
# Calculate the bubble size ratio for plotting
df_bubble_size_dQ = bviz.calculate_bubble_size_ratio(
    df_variable=df_features_per_cell["max_diff_dQ"])

df_bubble_size_dV = bviz.calculate_bubble_size_ratio(
    df_variable=df_features_per_cell["max_diff_dV"])

bubble_size = (
    np.abs(df_bubble_size_dV)
    * np.abs(df_bubble_size_dQ))
# Out:
# Feature mean: 0.00641125672398844
# Feature max: 0.042899057000000074
# Feature min: 0.006194469999999952
# Feature std: 0.0019646872892444154
# **********************************************************************
# Feature mean: 0.04105323627167629
# Feature max: 2.612268400000005
# Feature min: 0.022684100000000207
# Feature std: 0.11397361246602544
# **********************************************************************

# %% [markdown]
# ## Plot the bubble chart and label the true outliers

# %%
# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=df_features_per_cell["log_max_diff_dQ"],
    yseries=df_features_per_cell["log_max_diff_dV"],
    bubble_size=bubble_size,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=true_outlier_cycle_index)

axplot.set_title(
    f"Cell {selected_cell_label}", fontsize=13)

axplot.set_xlabel(
    r"$\log(\Delta Q_\textrm{scaled,max,cyc)}\;\textrm{[Ah]}$",
    fontsize=12)
axplot.set_ylabel(
    r"$\log(\Delta V_\textrm{scaled,max,cyc})\;\textrm{[V]}$",
    fontsize=12)

output_fig_filename = (
    "log_bubble_plot_"
    + selected_cell_label
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir.joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=200,
    bbox_inches="tight")

plt.show()
# Out:
# Potential anomalous cycle: 0.0
# x-position of the text: -5.053343441284631
# y-position of the text: 0.44734305691240445
# ----------------------------------------------------------------------
# Potential anomalous cycle: 40.0
# x-position of the text: -5.066424997988364
# y-position of the text: 0.9602189626435208
# ----------------------------------------------------------------------
# Potential anomalous cycle: 147.0
# x-position of the text: -3.1508950320267735
# y-position of the text: -3.5256965450993665
# ----------------------------------------------------------------------
# Potential anomalous cycle: 148.0
# x-position of the text: -3.1489054346417387
# y-position of the text: -3.6794044837514233
# ----------------------------------------------------------------------
