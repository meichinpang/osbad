# %% [markdown]
# # Import libraries

# %%
# %load_ext autoreload
# %autoreload 2

# Standard library
from pathlib import Path
import pprint

# Third-party libraries
import duckdb
import fireducks.pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import optuna
from matplotlib import rcParams

rcParams["text.usetex"] = True

# Custom osbad library for anomaly detection
import osbad.config as bconf
import osbad.hyperparam as hp
import osbad.modval as modval
import osbad.stats as bstats
import osbad.viz as bviz
from osbad.database import BenchDB
from osbad.scaler import CycleScaling
from osbad.model import ModelRunner

# %% [markdown]
# # Import dataset

# %% [markdown]
# ## Define filepath

# %%
# Define a global variable to save fig output
# The definition of PIPELINE_OUTPUT_DIR can be
# found in config.py
PIPELINE_OUTPUT_DIR = bconf.PIPELINE_OUTPUT_DIR

# %%
# Load only the training dataset
db_filepath = str(
    Path.cwd()
    .parent
    .joinpath("database","train_dataset_severson.db"))

# %% [markdown]
# ## Get the cell inventory of the training dataset

# %%
# Create a DuckDB connection
con = duckdb.connect(
    db_filepath,
    read_only=True)

# Load all training dataset from duckdb
df_duckdb = con.execute(
    "SELECT * FROM df_train_dataset_sv").fetchdf()

# Get the cell index of training dataset
unique_cell_index_train = df_duckdb["cell_index"].unique()
print(f"Unique cell index: {unique_cell_index_train}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Unique cell index: ['2017-05-12_5_4C-50per_3C_CH13' '2017-05-12_5_4C-50per_3C_CH14'
#  '2017-05-12_5_4C-60per_3C_CH15' '2017-05-12_5_4C-60per_3C_CH16'
#  '2017-05-12_5_4C-70per_3C_CH17' '2017-05-12_5_4C-70per_3C_CH18'
#  '2017-05-12_6C-40per_3C_CH25' '2017-05-12_6C-40per_3C_CH26'
#  '2017-05-12_6C-50per_3C_CH27' '2017-05-12_6C-50per_3C_CH28'
#  '2017-05-12_6C-60per_3C_CH29' '2017-05-12_6C-60per_3C_CH30'
#  '2017-05-12_7C-40per_3C_CH37' '2017-05-12_7C-40per_3C_CH38'
#  '2017-05-12_4C-80per_4C_CH5' '2017-05-12_4C-80per_4C_CH6'
#  '2017-05-12_4_4C-80per_4_4C_CH7' '2017-05-12_5_4C-80per_5_4C_CH11'
#  '2017-05-12_5_4C-80per_5_4C_CH12' '2017-05-12_3_6C-80per_3_6C_CH1'
#  '2017-05-12_3_6C-80per_3_6C_CH2' '2017-05-12_3_6C-80per_3_6C_CH3'
#  '2017-05-12_5_4C-40per_3_6C_CH19']

# %%
# Get the cell-ID from cell_inventory
selected_cell_label = "2017-05-12_5_4C-70per_3C_CH17"

# Create a subfolder to store fig output
# corresponding to each cell-index
selected_cell_artifacts_dir = bconf.artifacts_output_dir(
    selected_cell_label)

# %% [markdown]
# ## Drop true labels
#
# * Drop true outlier labels (denoted as ``outlier``) from the dataframe and select only relevant features for ML:
#   * ``cell_index``: The cell-ID for data and model versioning purposes;
#   * ``cycle_index``: The cycle number of each cell;
#   * ``discharge_capacity``: Discharge capacity of the cell;
#   * ``voltage``: Discharge voltage of the cell.

# %%
# Import the BenchDB class
# Load only the dataset based on the selected cell
benchdb = BenchDB(
    db_filepath,
    selected_cell_label)

# load the benchmarking dataset
df_selected_cell = benchdb.load_benchmark_dataset(
    dataset_type="train")

if df_selected_cell is not None:

    filter_col = [
        "cell_index",
        "cycle_index",
        "discharge_capacity",
        "voltage"]

    # Drop true labels from the benchmarking dataset
    # and filter for selected columns only
    df_selected_cell_without_labels = benchdb.drop_labels(
        df_selected_cell,
        filter_col)
# Out:
# Database is found in the given filepath.
# Loading benchmarking dataset now...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ****************************************************************************************************

# %% [markdown]
# ## Plot cycling data without labels

# %%
# If the true outlier cycle index is not known,
# cycling data will be plotted without labels
benchdb.plot_cycle_data(
    df_selected_cell_without_labels)

plt.show()

# %% [markdown]
# # Statistical Feature Transformation
#
# To help with the separation of abnormal cycles from normal cycles, we propose a new statistical feature transformation method using the median and IQR of the input features:
#
# $$
# \begin{equation}
# x_\textrm{scaled} = x_i - \left[\frac{\textrm{median}(X)^{2}}{\textrm{IQR}(X)}\right],
# \end{equation}
# $$
#
# where the IQR can be calculated from the third ($75^\textrm{th}$ percentile) and first quartile ($25^\textrm{th}$ percentile) of the input vector ($\textrm{IQR}(X) = Q_3(X) - Q_1(X)$). Here, we use $\textrm{median}(X)^2$ to preserve the physical unit of the original feature after feature transformation. Feature scaling is implemented on both the capacity and voltage data.
#
# ## Capacity scaling

# %%
# Instantiate the CycleScaling class
scaler = CycleScaling(
    df_selected_cell=df_selected_cell_without_labels)

# Implement median IQR scaling on the discharge capacity data
df_capacity_med_scaled = scaler.median_IQR_scaling(
    variable="discharge_capacity",
    validate=True)

# Plot the histogram and boxplot of the scaled data
ax_hist = bviz.hist_boxplot(
    df_variable=df_capacity_med_scaled["scaled_discharge_capacity"])

ax_hist.set_xlabel(
    r"Discharge capacity, $Q_\textrm{dis}$ [Ah]",
    fontsize=12)
ax_hist.set_ylabel(
    r"Count",
    fontsize=12)

output_fig_filename = (
    "cap_scaling_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# Print the summary statistics of the scaled capacity data
print(df_capacity_med_scaled["scaled_discharge_capacity"].describe())
print("*"*70)

df_capacity_med_scaled["scaled_discharge_capacity"]
# Out:
# count    313326.000000
# mean         -0.349626
# std           0.414280
# min          -2.933561
# 25%          -0.677412
# 50%          -0.226724
# 75%           0.005721
# max           0.844670
# Name: scaled_discharge_capacity, dtype: float64
# **********************************************************************
# 0        -0.828787
# 1        -0.827432
# 2        -0.825870
# 3        -0.824306
# 4        -0.824306
#             ...
# 301553   -0.145985
# 301554   -0.145915
# 301555   -0.145915
# 301556   -0.145867
# 301557   -0.145867
# Name: scaled_discharge_capacity, Length: 313326, dtype: float64

# %% [markdown]
# ## Voltage scaling

# %%
# Implement median IQR scaling on the discharge voltage data
df_voltage_med_scaled = scaler.median_IQR_scaling(
    variable="voltage",
    validate=True)

# Plot the histogram and boxplot of the scaled data
ax_hist = bviz.hist_boxplot(
    df_variable=df_voltage_med_scaled["scaled_voltage"])

ax_hist.set_xlabel(
    r"Scaled voltage, $V_\textrm{dis}$ [V]",
    fontsize=12)
ax_hist.set_ylabel(
    r"Count",
    fontsize=12)

output_fig_filename = (
    "voltage_scaling_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# Print the summary statistics of the scaled capacity data
print(df_voltage_med_scaled["scaled_voltage"].describe())
print("*"*70)
df_voltage_med_scaled["scaled_voltage"]
# Out:
# count    313326.000000
# mean         -6.557421
# std           7.159671
# min         -45.644671
# 25%          -5.844655
# 50%          -5.215267
# 75%          -4.672330
# max          -2.395836
# Name: scaled_voltage, dtype: float64
# **********************************************************************
# 0        -12.262836
# 1        -12.272870
# 2        -12.276842
# 3        -12.279593
# 4        -12.279593
#             ...
# 301553    -4.257652
# 301554    -4.257553
# 301555    -4.257553
# 301556    -4.257912
# 301557    -4.254364
# Name: scaled_voltage, Length: 313326, dtype: float64

# %% [markdown]
# ## Scatter histogram
#
# * Create scatterplot with histogram to display the distribution for x-axis and y-axis:
#   * The salmon color corresponds to x-axis (``scaled_capacity``)
#   * The grey color corresponds to y-axis (``scaled_voltage``)

# %%
axplot = bviz.scatterhist(
    xseries=df_selected_cell_without_labels["discharge_capacity"],
    yseries=df_selected_cell_without_labels["voltage"],
    cycle_index_series=df_selected_cell_without_labels["cycle_index"],
    selected_cell_label=selected_cell_label)

axplot.set_xlabel(
    r"Capacity, $Q_\textrm{dis}$ [Ah]",
    fontsize=12)
axplot.set_ylabel(
    r"Voltage, $V_\textrm{dis}$ [V]",
    fontsize=12)

output_fig_filename = (
    "scatterhist_no_scaling_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %%
axplot = bviz.scatterhist(
    xseries=df_capacity_med_scaled["scaled_discharge_capacity"],
    yseries=df_voltage_med_scaled["scaled_voltage"],
    cycle_index_series=df_selected_cell_without_labels["cycle_index"])

axplot.set_xlabel(
    r"Scaled capacity, $Q_\textrm{dis}$ [Ah]",
    fontsize=12)
axplot.set_ylabel(
    r"Scaled voltage, $V_\textrm{dis}$ [V]",
    fontsize=12)

output_fig_filename = (
    "scatterhist_with_scaling_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Physics-informed Feature Extraction
#
# * As the anomalies in this dataset are collective due to a continuous series of abnormal voltage and current measurements, we can transform the collective anomalies of a given cycle into cycle-wise point anomalies.
# * Use $\Delta V$ to detect any anomalies in the voltage data
# * Because our focus is on detecting anomalous cycle (multiple collective outliers and not a single data point), we are only interested in the maximum $\Delta V$ per cycle.
# * Drop the first and last 10 data points to exclude instantaneous voltage jump due to voltage relaxation at the beginning and at the end because of current interruptions. These are normal voltage behaviour, not considered as anomaly.
# * If continuous abnormal voltage and current measurements are recorded in a cycle, the specific cycle will be labelled as anomalous cycle.
#
# $$
# \begin{align}
# \Delta Q_\textrm{scaled,max,cyc} &= \underset{\textrm{cyc}}{\max}(Q_{\textrm{scaled},{k+1}} - Q_{\textrm{scaled},{k}}), \\
# \Delta V_\textrm{scaled,max,cyc} &= \underset{\textrm{cyc}}{\max}(V_{\textrm{scaled},{k+1}} - V_{\textrm{scaled},{k}}),
# \end{align}
# $$
#
# where $\Delta V_\textrm{scaled,max,cyc}$ is the maximum scaled voltage difference per cycle and $\Delta Q_\textrm{scaled,max,cyc}$ is the maximum scaled capacity difference per cycle. $k$ in these equations denote the index of each recorded data point.
#
# * Don't use the natural index of the dataframe as the cycle index
# * Create an additional column for the cycle_index so that we can keep track of the true cycle_index even after removing some anomalous cycle from the df

# %% [markdown]
# ## Feature max dV

# %%
# maximum scaled voltage difference per cycle
df_max_dV = scaler.calculate_max_diff_per_cycle(
    df_scaled=df_voltage_med_scaled,
    variable_name="scaled_voltage")

df_max_dV
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>max_diff</th>
#       <th>log_max_diff</th>
#       <th>cycle_index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.564151</td>
#       <td>0.447343</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.023727</td>
#       <td>-3.741163</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.022684</td>
#       <td>-3.786091</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.027899</td>
#       <td>-3.579172</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.026408</td>
#       <td>-3.634081</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>687</th>
#       <td>0.046420</td>
#       <td>-3.070023</td>
#       <td>687.0</td>
#     </tr>
#     <tr>
#       <th>688</th>
#       <td>0.051542</td>
#       <td>-2.965352</td>
#       <td>688.0</td>
#     </tr>
#     <tr>
#       <th>689</th>
#       <td>0.047776</td>
#       <td>-3.041228</td>
#       <td>689.0</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>0.046331</td>
#       <td>-3.071935</td>
#       <td>690.0</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>0.047873</td>
#       <td>-3.039193</td>
#       <td>691.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>692 rows x 3 columns</p>
# </div>

# %%
max_dV_feature_stats = bstats.calculate_feature_stats(
    df_max_dV["max_diff"],
    new_col_name="max_diff_dV")

max_dV_feature_stats
# Out:
# Feature mean: 0.04105323627167629
# Feature max: 2.612268400000005
# Feature min: 0.022684100000000207
# Feature std: 0.11397361246602544
# **********************************************************************
#       max_diff_dV
# max        2.6123
# min        0.0227
# mean       0.0411
# std        0.1140

# %% [markdown]
# ## Feature max dQ

# %%
# maximum scaled capacity difference per cycle
df_max_dQ = scaler.calculate_max_diff_per_cycle(
    df_scaled=df_capacity_med_scaled,
    variable_name="scaled_discharge_capacity")

df_max_dQ
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>max_diff</th>
#       <th>log_max_diff</th>
#       <th>cycle_index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.006388</td>
#       <td>-5.053343</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.006338</td>
#       <td>-5.061258</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.006321</td>
#       <td>-5.063922</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.006259</td>
#       <td>-5.073756</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.006236</td>
#       <td>-5.077346</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>687</th>
#       <td>0.006236</td>
#       <td>-5.077391</td>
#       <td>687.0</td>
#     </tr>
#     <tr>
#       <th>688</th>
#       <td>0.006281</td>
#       <td>-5.070178</td>
#       <td>688.0</td>
#     </tr>
#     <tr>
#       <th>689</th>
#       <td>0.006243</td>
#       <td>-5.076238</td>
#       <td>689.0</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>0.006316</td>
#       <td>-5.064619</td>
#       <td>690.0</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>0.006402</td>
#       <td>-5.051123</td>
#       <td>691.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>692 rows x 3 columns</p>
# </div>

# %%
max_dQ_feature_stats = bstats.calculate_feature_stats(
    df_max_dQ["max_diff"],
    new_col_name="max_diff_dQ")

max_dQ_feature_stats
# Out:
# Feature mean: 0.00641125672398844
# Feature max: 0.042899057000000074
# Feature min: 0.006194469999999952
# Feature std: 0.0019646872892444154
# **********************************************************************
#       max_diff_dQ
# max        0.0429
# min        0.0062
# mean       0.0064
# std        0.0020

# %% [markdown]
# ## Feature max dVdQ

# %%
df_max_dVdQ = scaler.calculate_max_feature_derivative_per_cycle(
    Xfeature=df_capacity_med_scaled["scaled_discharge_capacity"],
    Yfeature=df_voltage_med_scaled["scaled_voltage"],
    cycle_index=df_voltage_med_scaled["cycle_index"])

df_max_dVdQ
# Out:
# /home/mei-chin-pang/02_academics/osbad_development/osbad/src/osbad/scaler.py:262: RuntimeWarning: divide by zero encountered in divide
#   feature_diff = numerator_feature_diff/denominator_feature_diff
# /home/mei-chin-pang/02_academics/osbad_development/osbad/src/osbad/scaler.py:262: RuntimeWarning: invalid value encountered in divide
#   feature_diff = numerator_feature_diff/denominator_feature_diff
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>max_diff</th>
#       <th>log_max_diff</th>
#       <th>cycle_index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>178932.163746</td>
#       <td>12.094762</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.879725</td>
#       <td>2.386901</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9.355405</td>
#       <td>2.235954</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7.779197</td>
#       <td>2.051453</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9.119772</td>
#       <td>2.210445</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>687</th>
#       <td>8.897922</td>
#       <td>2.185818</td>
#       <td>687.0</td>
#     </tr>
#     <tr>
#       <th>688</th>
#       <td>7.007765</td>
#       <td>1.947019</td>
#       <td>688.0</td>
#     </tr>
#     <tr>
#       <th>689</th>
#       <td>7.087613</td>
#       <td>1.958349</td>
#       <td>689.0</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>7.316459</td>
#       <td>1.990126</td>
#       <td>690.0</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>54.619562</td>
#       <td>4.000392</td>
#       <td>691.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>692 rows x 3 columns</p>
# </div>

# %%
max_dVdQ_feature_stats = bstats.calculate_feature_stats(
    df_max_dVdQ["max_diff"],
    new_col_name="max_diff_dVdQ")

max_dVdQ_feature_stats
# Out:
# Feature mean: 321.2474799595722
# Feature max: 178932.16374587023
# Feature min: 4.1214299224441175
# Feature std: 6918.580867088767
# **********************************************************************
#       max_diff_dVdQ
# max     178932.1637
# min          4.1214
# mean       321.2475
# std       6918.5809

# %% [markdown]
# # Modified Z-score
#
# $$
# \begin{equation}
# \textrm{Modified Z-score} = \frac{x_i - \textrm{median}(X)}{\textrm{MAD}},
# \end{equation}
# $$
#
# * A coefficient of 0.6745 is sometimes added to the numerator of Equation to make the modified z-score equivalent to the standard Z-score in a Gaussian distribution.
# * This coefficient is actually the reciprocal of the MAD-factor ($F_\textrm{MAD} = 1.4826$).
# * If the distribution is not Gaussian, then this coefficient should be calculated from the 75th-percentile of the corresponding standard distribution.

# %% [markdown]
# # Feature: dV
#
# ## Modified Z-score on dV (flexible MAD-factor)
#
# * The default MAD factor is ``None``, which means $F_\textrm{MAD}$ can be calculated from the reciprocal of the 75th-percentile of a standard distribution (a distribution with a mean of zero and a standard deviation of one).

# %%
# Access the dict of parameters for using 
# the ModZ method
mod_zscore_param_dict = bstats.outlier_method["mod_zscore"].params
print(mod_zscore_param_dict)
# Out:
# {'mad_factor': None, 'mod_zscore_threshold': 3.5, 'ddof': 1}

# %%
(mod_zscore_outlier_index_dV,
 mod_zscore_min_limit_dV,
 mod_zscore_max_limit_dV) = bstats.outlier_method["mod_zscore"].compute(
    df_max_dV["max_diff"], 
    **mod_zscore_param_dict)

print("*"*70)
print(f"ModZ outlier index on dV: {mod_zscore_outlier_index_dV}")
print(df_max_dV[df_max_dV["cycle_index"].isin(mod_zscore_outlier_index_dV)])
print("*"*70)
# Out:
# Feature median: 0.034730899999999565
# Feature z-score mean: 0.0
# Feature z-score std. deviation: 1.0
# MAD: 0.13799320920852684
# Modified Zmin limit: -3.5
# Modified Zmax limit: 3.5
# **********************************************************************
# ModZ outlier index on dV: [ 0 40]
#     max_diff  log_max_diff  cycle_index
# 0   1.564151      0.447343          0.0
# 40  2.612268      0.960219         40.0
# **********************************************************************

# %% [markdown]
# ### Bubble plot

# %%
unique_cycle_count = (
    df_selected_cell_without_labels["cycle_index"]
    .unique())

df_bubble_size_dV = bviz.calculate_bubble_size_ratio(
    df_variable=df_max_dV["max_diff"])

# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=unique_cycle_count,
    yseries=df_max_dV["max_diff"],
    bubble_size=df_bubble_size_dV,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=mod_zscore_outlier_index_dV)

axplot.set_xlabel(
    r"Cycle number, $N_\textrm{cyc}$ [-]",
    fontsize=12)

axplot.set_ylabel(
    r"$\Delta V_\textrm{scaled,max,cyc}\;\textrm{[V]}$",
    fontsize=12)

fig_title=(r"Modified Z-score on $\Delta V_\textrm{scaled,max,cyc}$")

axplot.set_title(
    fig_title,
    fontsize=16)

output_fig_filename = (
    "modz_flex_dv_bubble_plot_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Feature mean: 0.04105323627167629
# Feature max: 2.612268400000005
# Feature min: 0.022684100000000207
# Feature std: 0.11397361246602544
# **********************************************************************
# Potential anomalous cycle: 0.0
# x-position of the text: 0.0
# y-position of the text: 1.5641508000000002
# ----------------------------------------------------------------------
# Potential anomalous cycle: 40.0
# x-position of the text: 40.0
# y-position of the text: 2.612268400000005
# ----------------------------------------------------------------------

# %% [markdown]
# ### Confusion matrix

# %%
# Compare Modified Z-score predicted anomalies with true anomalies
df_eval_outlier_modz_dV = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=mod_zscore_outlier_index_dV)

# Generate custom confusion matrix
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier_modz_dV["true_outlier"],
    y_pred=df_eval_outlier_modz_dV["pred_outlier"])

fig_title=(r"Modified Z-score on $\Delta V_\textrm{scaled,max,cyc}$ \newline")

axplot.set_title(
    fig_title 
    + "\n",
    fontsize=16)

output_fig_filename = (
    "modz_flex_conf_matrix_dv_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Modified Z-score on dV (MAD-factor = 1.4826)
#
# * Let's also evaluate the result with ``MAD-factor = 1.4826``

# %%
# Create a copy of the default dict parameter
modz_param_dict_const = bstats.outlier_method["mod_zscore"].params.copy()
print(modz_param_dict_const)

# Update the dict value to be 1.4826
modz_param_dict_const["mad_factor"] = 1.4826
print(modz_param_dict_const)
# Out:
# {'mad_factor': None, 'mod_zscore_threshold': 3.5, 'ddof': 1}
# {'mad_factor': 1.4826, 'mod_zscore_threshold': 3.5, 'ddof': 1}

# %%
(mod_zscore_outlier_index_dV_const,
 mod_zscore_min_limit_dV_const,
 mod_zscore_max_limit_dV_const) = bstats.outlier_method["mod_zscore"].compute(
    df_max_dV["max_diff"], 
    **modz_param_dict_const)

print("*"*70)
print(f"Modified Z-score outlier index on dV: {mod_zscore_outlier_index_dV_const}")
print(df_max_dV[df_max_dV["cycle_index"].isin(mod_zscore_outlier_index_dV_const)])
print("*"*70)
# Out:
# Feature median: 0.034730899999999565
# MAD: 0.005272496249999892
# Modified Zmin limit: -3.5
# Modified Zmax limit: 3.5
# **********************************************************************
# Modified Z-score outlier index on dV: [ 0 40]
#     max_diff  log_max_diff  cycle_index
# 0   1.564151      0.447343          0.0
# 40  2.612268      0.960219         40.0
# **********************************************************************

# %% [markdown]
# ### Bubble plot

# %%
unique_cycle_count = (
    df_selected_cell_without_labels["cycle_index"]
    .unique())

df_bubble_size_dV = bviz.calculate_bubble_size_ratio(
    df_variable=df_max_dV["max_diff"])

# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=unique_cycle_count,
    yseries=df_max_dV["max_diff"],
    bubble_size=df_bubble_size_dV,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=mod_zscore_outlier_index_dV_const)

axplot.set_xlabel(
    r"Cycle number, $N_\textrm{cyc}$ [-]",
    fontsize=12)

axplot.set_ylabel(
    r"$\Delta V_\textrm{scaled,max,cyc}\;\textrm{[V]}$",
    fontsize=12)

fig_title=(r"Modified Z-score on $\Delta V_\textrm{scaled,max,cyc}$ (MAD-factor=1.4826) \newline")

axplot.set_title(
    fig_title,
    fontsize=16)


output_fig_filename = (
    "modz_const_dv_bubble_plot_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Feature mean: 0.04105323627167629
# Feature max: 2.612268400000005
# Feature min: 0.022684100000000207
# Feature std: 0.11397361246602544
# **********************************************************************
# Potential anomalous cycle: 0.0
# x-position of the text: 0.0
# y-position of the text: 1.5641508000000002
# ----------------------------------------------------------------------
# Potential anomalous cycle: 40.0
# x-position of the text: 40.0
# y-position of the text: 2.612268400000005
# ----------------------------------------------------------------------

# %% [markdown]
# ### Confusion matrix

# %%
# Compare Modified Z-score predicted anomalies with true anomalies
df_eval_outlier_modz_dV = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=mod_zscore_outlier_index_dV_const)

# Generate custom confusion matrix
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier_modz_dV["true_outlier"],
    y_pred=df_eval_outlier_modz_dV["pred_outlier"])

fig_title=(
    r"Modified Z-score on $\Delta V_\textrm{scaled,max,cyc}$ (MAD-factor=1.4826) \newline")

axplot.set_title(
    fig_title 
    + "\n",
    fontsize=16)

output_fig_filename = (
    "modz_const_conf_matrix_dv_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Feature: dQ
#
# ## Modified Z-score on dQ (flexible MAD-factor)

# %%
(mod_zscore_outlier_index_dQ,
 mod_zscore_min_limit_dQ,
 mod_zscore_max_limit_dQ) = bstats.outlier_method["mod_zscore"].compute(
    df_max_dQ["max_diff"], 
    **mod_zscore_param_dict)

print("*"*70)
print(f"Modified Z-score outlier index on dQ: {mod_zscore_outlier_index_dQ}")
print(df_max_dQ[df_max_dQ["cycle_index"].isin(mod_zscore_outlier_index_dQ)])
print("*"*70)
# Out:
# Feature median: 0.006289509999999998
# Feature z-score mean: 0.0
# Feature z-score std. deviation: 1.0
# MAD: 0.0008305427477439969
# Modified Zmin limit: -3.5
# Modified Zmax limit: 3.5
# **********************************************************************
# Modified Z-score outlier index on dQ: [147 148]
#      max_diff  log_max_diff  cycle_index
# 147  0.042814     -3.150895        147.0
# 148  0.042899     -3.148905        148.0
# **********************************************************************

# %% [markdown]
# ### Bubble plot

# %%
unique_cycle_count = (
    df_selected_cell_without_labels["cycle_index"]
    .unique())

df_bubble_size_dQ = bviz.calculate_bubble_size_ratio(
    df_variable=df_max_dQ["max_diff"])

# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=unique_cycle_count,
    yseries=df_max_dQ["max_diff"],
    bubble_size=df_bubble_size_dQ,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=mod_zscore_outlier_index_dQ)

axplot.set_xlabel(
    r"Cycle number, $N_\textrm{cyc}$ [-]",
    fontsize=12)

axplot.set_ylabel(
    r"$\Delta Q_\textrm{scaled,max,cyc}\;\textrm{[V]}$",
    fontsize=12)

fig_title=(r"Modified Z-score on $\Delta Q_\textrm{scaled,max,cyc}$")

axplot.set_title(
    fig_title,
    fontsize=16)

output_fig_filename = (
    "modz_flex_dq_bubble_plot_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Feature mean: 0.00641125672398844
# Feature max: 0.042899057000000074
# Feature min: 0.006194469999999952
# Feature std: 0.0019646872892444154
# **********************************************************************
# Potential anomalous cycle: 147.0
# x-position of the text: 147.0
# y-position of the text: 0.04281378999999996
# ----------------------------------------------------------------------
# Potential anomalous cycle: 148.0
# x-position of the text: 148.0
# y-position of the text: 0.042899057000000074
# ----------------------------------------------------------------------

# %% [markdown]
# ### Confusion matrix

# %%
# Compare Modified Z-score predicted anomalies with true anomalies
df_eval_outlier_modz_dQ = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=mod_zscore_outlier_index_dQ)

# Generate custom confusion matrix
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier_modz_dQ["true_outlier"],
    y_pred=df_eval_outlier_modz_dQ["pred_outlier"])

fig_title=(r"Modified Z-score on $\Delta Q_\textrm{scaled,max,cyc}$ \newline")

axplot.set_title(
    fig_title 
    + "\n",
    fontsize=16)

output_fig_filename = (
    "modz_flex_conf_matrix_dq_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Modified Z-score on dQ (MAD-factor = 1.4826)
#
# * Let's also evaluate the result with ``MAD-factor = 1.4826``

# %%
(mod_zscore_outlier_index_dQ_const,
 mod_zscore_min_limit_dQ_const,
 mod_zscore_max_limit_dQ_const) = bstats.outlier_method["mod_zscore"].compute(
    df_max_dQ["max_diff"], 
    **modz_param_dict_const)

print("*"*70)
print(f"Modified Z-score outlier index on dQ: {mod_zscore_outlier_index_dQ_const}")
print(df_max_dQ[df_max_dQ["cycle_index"].isin(mod_zscore_outlier_index_dQ_const)])
print("*"*70)
# Out:
# Feature median: 0.006289509999999998
# MAD: 4.844395500005565e-05
# Modified Zmin limit: -3.5
# Modified Zmax limit: 3.5
# **********************************************************************
# Modified Z-score outlier index on dQ: [ 15  16  23  26  32  39  70 136 144 147 148 222 227 240 268 321 324 369
#  418 448 538 685]
#      max_diff  log_max_diff  cycle_index
# 15   0.006524     -5.032257         15.0
# 16   0.006556     -5.027451         16.0
# 23   0.006594     -5.021527         23.0
# 26   0.006467     -5.041082         26.0
# 32   0.006912     -4.974528         32.0
# 39   0.006468     -5.040963         39.0
# 70   0.006490     -5.037430         70.0
# 136  0.006497     -5.036365        136.0
# 144  0.006485     -5.038316        144.0
# 147  0.042814     -3.150895        147.0
# 148  0.042899     -3.148905        148.0
# 222  0.006462     -5.041892        222.0
# 227  0.006590     -5.022164        227.0
# 240  0.006523     -5.032447        240.0
# 268  0.006565     -5.026038        268.0
# 321  0.006508     -5.034660        321.0
# 324  0.006564     -5.026175        324.0
# 369  0.006469     -5.040723        369.0
# 418  0.006460     -5.042169        418.0
# 448  0.006467     -5.041117        448.0
# 538  0.006503     -5.035436        538.0
# 685  0.006664     -5.011083        685.0
# **********************************************************************

# %% [markdown]
# ### Bubble plot

# %%
unique_cycle_count = (
    df_selected_cell_without_labels["cycle_index"]
    .unique())

df_bubble_size_dQ = bviz.calculate_bubble_size_ratio(
    df_variable=df_max_dQ["max_diff"])

# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=unique_cycle_count,
    yseries=df_max_dQ["max_diff"],
    bubble_size=df_bubble_size_dQ,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=mod_zscore_outlier_index_dQ_const)

axplot.set_xlabel(
    r"Cycle number, $N_\textrm{cyc}$ [-]",
    fontsize=12)

axplot.set_ylabel(
    r"$\Delta Q_\textrm{scaled,max,cyc}\;\textrm{[V]}$",
    fontsize=12)

fig_title=(r"Modified Z-score on $\Delta Q_\textrm{scaled,max,cyc}$ (MAD-factor=1.4826) \newline")

axplot.set_title(
    fig_title,
    fontsize=16)


output_fig_filename = (
    "modz_const_dq_bubble_plot_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Feature mean: 0.00641125672398844
# Feature max: 0.042899057000000074
# Feature min: 0.006194469999999952
# Feature std: 0.0019646872892444154
# **********************************************************************
# Potential anomalous cycle: 15.0
# x-position of the text: 15.0
# y-position of the text: 0.006524070000000104
# ----------------------------------------------------------------------
# Potential anomalous cycle: 16.0
# x-position of the text: 16.0
# y-position of the text: 0.006555500000000047
# ----------------------------------------------------------------------
# Potential anomalous cycle: 23.0
# x-position of the text: 23.0
# y-position of the text: 0.006594449999999918
# ----------------------------------------------------------------------
# Potential anomalous cycle: 26.0
# x-position of the text: 26.0
# y-position of the text: 0.006466750000000077
# ----------------------------------------------------------------------
# Potential anomalous cycle: 32.0
# x-position of the text: 32.0
# y-position of the text: 0.006911780000000034
# ----------------------------------------------------------------------
# Potential anomalous cycle: 39.0
# x-position of the text: 39.0
# y-position of the text: 0.006467519999999949
# ----------------------------------------------------------------------
# Potential anomalous cycle: 70.0
# x-position of the text: 70.0
# y-position of the text: 0.0064904100000000575
# ----------------------------------------------------------------------
# Potential anomalous cycle: 136.0
# x-position of the text: 136.0
# y-position of the text: 0.006497320000000029
# ----------------------------------------------------------------------
# Potential anomalous cycle: 144.0
# x-position of the text: 144.0
# y-position of the text: 0.0064846599999999754
# ----------------------------------------------------------------------
# Potential anomalous cycle: 147.0
# x-position of the text: 147.0
# y-position of the text: 0.04281378999999996
# ----------------------------------------------------------------------
# Potential anomalous cycle: 148.0
# x-position of the text: 148.0
# y-position of the text: 0.042899057000000074
# ----------------------------------------------------------------------
# Potential anomalous cycle: 222.0
# x-position of the text: 222.0
# y-position of the text: 0.006461510000000059
# ----------------------------------------------------------------------
# Potential anomalous cycle: 227.0
# x-position of the text: 227.0
# y-position of the text: 0.00659025000000002
# ----------------------------------------------------------------------
# Potential anomalous cycle: 240.0
# x-position of the text: 240.0
# y-position of the text: 0.0065228299999999795
# ----------------------------------------------------------------------
# Potential anomalous cycle: 268.0
# x-position of the text: 268.0
# y-position of the text: 0.0065647699999999976
# ----------------------------------------------------------------------
# Potential anomalous cycle: 321.0
# x-position of the text: 321.0
# y-position of the text: 0.00650841000000002
# ----------------------------------------------------------------------
# Potential anomalous cycle: 324.0
# x-position of the text: 324.0
# y-position of the text: 0.006563870000000027
# ----------------------------------------------------------------------
# Potential anomalous cycle: 369.0
# x-position of the text: 369.0
# y-position of the text: 0.006469070000000077
# ----------------------------------------------------------------------
# Potential anomalous cycle: 418.0
# x-position of the text: 418.0
# y-position of the text: 0.006459719999999947
# ----------------------------------------------------------------------
# Potential anomalous cycle: 448.0
# x-position of the text: 448.0
# y-position of the text: 0.00646651999999992
# ----------------------------------------------------------------------
# Potential anomalous cycle: 538.0
# x-position of the text: 538.0
# y-position of the text: 0.006503360000000069
# ----------------------------------------------------------------------
# Potential anomalous cycle: 685.0
# x-position of the text: 685.0
# y-position of the text: 0.006663680000000061
# ----------------------------------------------------------------------

# %% [markdown]
# ### Confusion matrix

# %%
# Compare Modified Z-score predicted anomalies with true anomalies
df_eval_outlier_modz_dQ = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=mod_zscore_outlier_index_dQ_const)

# Generate custom confusion matrix
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier_modz_dQ["true_outlier"],
    y_pred=df_eval_outlier_modz_dQ["pred_outlier"])

fig_title=(
    r"Modified Z-score on $\Delta Q_\textrm{scaled,max,cyc}$ (MAD-factor=1.4826) \newline")

axplot.set_title(
    fig_title 
    + "\n",
    fontsize=16)

output_fig_filename = (
    "modz_const_conf_matrix_dq_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Feature: dVdQ
#
# ## Modified Z-score on log(dVdQ) (flexible MAD-factor)

# %%
(mod_zscore_outlier_index_dVdQ,
 mod_zscore_min_limit_dVdQ,
 mod_zscore_max_limit_dVdQ) = bstats.outlier_method["mod_zscore"].compute(
    df_max_dVdQ["log_max_diff"], 
    **mod_zscore_param_dict)

print("*"*70)
print(f"Modified Z-score outlier index on dVdQ: {mod_zscore_outlier_index_dVdQ}")
print(df_max_dVdQ[df_max_dVdQ["cycle_index"].isin(mod_zscore_outlier_index_dVdQ)])
print("*"*70)
# Out:
# Feature median: 2.4804507281050907
# Feature z-score mean: -0.0
# Feature z-score std. deviation: 1.0
# MAD: 0.9391858202352404
# Modified Zmin limit: -3.5
# Modified Zmax limit: 3.5
# **********************************************************************
# Modified Z-score outlier index on dVdQ: [ 0 40]
#          max_diff  log_max_diff  cycle_index
# 0   178932.163746     12.094762          0.0
# 40   33622.153846     10.422940         40.0
# **********************************************************************

# %% [markdown]
# ### Bubble plot

# %%
unique_cycle_count = (
    df_selected_cell_without_labels["cycle_index"]
    .unique())

df_bubble_size_dVdQ = bviz.calculate_bubble_size_ratio(
    df_variable=df_max_dVdQ["max_diff"])

# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=unique_cycle_count,
    yseries=df_max_dVdQ["max_diff"],
    bubble_size=df_bubble_size_dVdQ,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=mod_zscore_outlier_index_dVdQ)

axplot.set_xlabel(
    r"Cycle number, $N_\textrm{cyc}$ [-]",
    fontsize=12)

axplot.set_ylabel(
    r"$(d\textrm{V}d\textrm{Q})_\textrm{scaled,max,cyc}\;\textrm{[V Ah$^{-1}$]}$",
    fontsize=12)

fig_title=(r"Modified Z-score on $d\textrm{V}d\textrm{Q}_\textrm{scaled,max,cyc}$ \newline")

axplot.set_title(
    fig_title,
    fontsize=16)

output_fig_filename = (
    "modz_flex_dvdq_bubble_plot_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Feature mean: 321.2474799595722
# Feature max: 178932.16374587023
# Feature min: 4.1214299224441175
# Feature std: 6918.580867088767
# **********************************************************************
# Potential anomalous cycle: 0.0
# x-position of the text: 0.0
# y-position of the text: 178932.16374587023
# ----------------------------------------------------------------------
# Potential anomalous cycle: 40.0
# x-position of the text: 40.0
# y-position of the text: 33622.15384614415
# ----------------------------------------------------------------------

# %% [markdown]
# ### Confusion matrix

# %%
# Compare Modified Z-score predicted anomalies with true anomalies
df_eval_outlier_modz_dVdQ = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=mod_zscore_outlier_index_dVdQ)

# Generate custom confusion matrix
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier_modz_dVdQ["true_outlier"],
    y_pred=df_eval_outlier_modz_dVdQ["pred_outlier"])

fig_title=(r"Modified Z-score on $\log(d\textrm{V}d\textrm{Q}_\textrm{scaled,max,cyc})$ \newline")

axplot.set_title(
    fig_title 
    + "\n",
    fontsize=16)

output_fig_filename = (
    "modz_flex_conf_matrix_dvdq_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Modified Z-score on log(dVdQ) (MAD-factor = 1.4826)
#
# * Let's also evaluate the result with ``MAD-factor = 1.4826``

# %%
(mod_zscore_outlier_index_dVdQ_const,
 mod_zscore_min_limit_dVdQ_const,
 mod_zscore_max_limit_dVdQ_const) = bstats.outlier_method["mod_zscore"].compute(
    df_max_dVdQ["log_max_diff"], 
    **modz_param_dict_const)

print("*"*70)
print(f"Modified Z-score outlier index on dVdQ: {mod_zscore_outlier_index_dVdQ_const}")
print(df_max_dVdQ[df_max_dVdQ["cycle_index"].isin(mod_zscore_outlier_index_dVdQ_const)])
print("*"*70)
# Out:
# Feature median: 2.4804507281050907
# MAD: 0.3620199591240475
# Modified Zmin limit: -3.5
# Modified Zmax limit: 3.5
# **********************************************************************
# Modified Z-score outlier index on dVdQ: [  0  40 643 680 691]
#           max_diff  log_max_diff  cycle_index
# 0    178932.163746     12.094762          0.0
# 40    33622.153846     10.422940         40.0
# 643      47.517896      3.861106        643.0
# 680      46.619760      3.842024        680.0
# 691      54.619562      4.000392        691.0
# **********************************************************************

# %% [markdown]
# ### Bubble plot

# %%
unique_cycle_count = (
    df_selected_cell_without_labels["cycle_index"]
    .unique())

df_bubble_size_dVdQ = bviz.calculate_bubble_size_ratio(
    df_variable=df_max_dVdQ["max_diff"])

# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=unique_cycle_count,
    yseries=df_max_dVdQ["max_diff"],
    bubble_size=df_bubble_size_dVdQ,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=mod_zscore_outlier_index_dVdQ_const)

axplot.set_xlabel(
    r"Cycle number, $N_\textrm{cyc}$ [-]",
    fontsize=12)

axplot.set_ylabel(
    r"$d\textrm{V}d\textrm{Q}_\textrm{scaled,max,cyc}\;\textrm{[V]}$",
    fontsize=12)

fig_title=(
    r"Modified Z-score on $d\textrm{V}d\textrm{Q}_\textrm{scaled,max,cyc}$ (MAD-factor=1.4826)\newline")

axplot.set_title(
    fig_title,
    fontsize=16)


output_fig_filename = (
    "modz_const_dvdq_bubble_plot_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Feature mean: 321.2474799595722
# Feature max: 178932.16374587023
# Feature min: 4.1214299224441175
# Feature std: 6918.580867088767
# **********************************************************************
# Potential anomalous cycle: 0.0
# x-position of the text: 0.0
# y-position of the text: 178932.16374587023
# ----------------------------------------------------------------------
# Potential anomalous cycle: 40.0
# x-position of the text: 40.0
# y-position of the text: 33622.15384614415
# ----------------------------------------------------------------------
# Potential anomalous cycle: 643.0
# x-position of the text: 643.0
# y-position of the text: 47.51789606238158
# ----------------------------------------------------------------------
# Potential anomalous cycle: 680.0
# x-position of the text: 680.0
# y-position of the text: 46.61975986075309
# ----------------------------------------------------------------------
# Potential anomalous cycle: 691.0
# x-position of the text: 691.0
# y-position of the text: 54.619562117079795
# ----------------------------------------------------------------------

# %% [markdown]
# ### Confusion matrix

# %%
# Compare Modified Z-score predicted anomalies with true anomalies
df_eval_outlier_modz_dVdQ = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=mod_zscore_outlier_index_dVdQ_const)

# Generate custom confusion matrix
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier_modz_dVdQ["true_outlier"],
    y_pred=df_eval_outlier_modz_dVdQ["pred_outlier"])

fig_title=(
    r"Modified Z-score on $\log(d\textrm{V}d\textrm{Q}_\textrm{scaled,max,cyc})$ (MAD-factor=1.4826)\newline")

axplot.set_title(
    fig_title 
    + "\n",
    fontsize=16)

output_fig_filename = (
    "modz_const_conf_matrix_dvdq_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Visualize potential anomalous cycles
#
# ## Multiple anomalous cycles
#
# * Plot and annotate multiple potential outlier cycles.

# %%
bviz.plot_multiple_outlier_cycles(
    df_selected_cell,
    potential_outlier_cycles= [0, 40],
    selected_cell_label=selected_cell_label)
# Out:
# Total subplot: 2
# Total rows: 1
# Total columns: 2
# **********************************************************************
# Plot outlier cycle: 0
# Plot outlier cycle: 40

# %% [markdown]
# ## Single anomalous cycle
#
# * Plot and annotate a single cycle as a potential outlier.

# %%
bviz.plot_single_outlier_cycle(
    df_selected_cell,
    selected_cycle_index=147,
    selected_cell_label=selected_cell_label)

# %% [markdown]
# # Plot cycle data with true outliers

# %%
# Import the BenchDB class
# Load only the dataset based on the selected cell
benchdb = BenchDB(
    db_filepath,
    selected_cell_label)

# load the benchmarking dataset
df_selected_cell = benchdb.load_benchmark_dataset(
    dataset_type="train")

if df_selected_cell is not None:

    filter_col = [
        "cell_index",
        "cycle_index",
        "discharge_capacity",
        "voltage"]

    # Drop true labels from the benchmarking dataset
    # and filter for selected columns only
    df_selected_cell_without_labels = benchdb.drop_labels(
        df_selected_cell,
        filter_col)

    # print a subset of the dataframe
    # for diagnostics running in terminals
    print(df_selected_cell_without_labels.head(10).to_markdown())
    print("*"*100)

    # Extract true outliers cycle index from benchmarking dataset
    true_outlier_cycle_index = benchdb.get_true_outlier_cycle_index(
        df_selected_cell)
    print(f"True outlier cycle index:")
    print(true_outlier_cycle_index)
# Out:
# Database is found in the given filepath.
# Loading benchmarking dataset now...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ****************************************************************************************************
# |    | cell_index                    |   cycle_index |   discharge_capacity |   voltage |
# |---:|:------------------------------|--------------:|---------------------:|----------:|
# |  0 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          1.26512e-05 |   3.29189 |
# |  1 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00136774  |   3.28185 |
# |  2 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00292998  |   3.27788 |
# |  3 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00449361  |   3.27513 |
# |  4 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00449361  |   3.27513 |
# |  5 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00605927  |   3.27299 |
# |  6 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00762155  |   3.27124 |
# |  7 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0091859   |   3.2703  |
# |  8 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0107469   |   3.26875 |
# |  9 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0123127   |   3.26787 |
# ****************************************************************************************************
# True outlier cycle index:
# [  0.  40. 147. 148.]

# %%
# Plot cell data with true anomalies
benchdb.plot_cycle_data(
    df_selected_cell_without_labels,
    true_outlier_cycle_index)

plt.show()
