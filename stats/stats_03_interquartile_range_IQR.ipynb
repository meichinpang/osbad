# %% [markdown]
# # Import libraries

# %%
# %load_ext autoreload
# %autoreload 2

# Standard library
from pathlib import Path
import pprint

# Third-party libraries
import duckdb
import fireducks.pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import optuna
from matplotlib import rcParams

rcParams["text.usetex"] = True

# Custom osbad library for anomaly detection
import osbad.config as bconf
import osbad.hyperparam as hp
import osbad.modval as modval
import osbad.stats as bstats
import osbad.viz as bviz
from osbad.database import BenchDB
from osbad.scaler import CycleScaling
from osbad.model import ModelRunner

# %% [markdown]
# # Import dataset

# %% [markdown]
# ## Define filepath

# %%
# Define a global variable to save fig output
# The definition of PIPELINE_OUTPUT_DIR can be
# found in config.py
PIPELINE_OUTPUT_DIR = bconf.PIPELINE_OUTPUT_DIR

# %%
# Load only the training dataset
db_filepath = str(
    Path.cwd()
    .parent
    .joinpath("database","train_dataset_severson.db"))

# %% [markdown]
# ## Get the cell inventory of the training dataset

# %%
# Create a DuckDB connection
con = duckdb.connect(
    db_filepath,
    read_only=True)

# Load all training dataset from duckdb
df_duckdb = con.execute(
    "SELECT * FROM df_train_dataset_sv").fetchdf()

# Get the cell index of training dataset
unique_cell_index_train = df_duckdb["cell_index"].unique()
print(f"Unique cell index: {unique_cell_index_train}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Unique cell index: ['2017-05-12_5_4C-50per_3C_CH13' '2017-05-12_5_4C-50per_3C_CH14'
#  '2017-05-12_5_4C-60per_3C_CH15' '2017-05-12_5_4C-60per_3C_CH16'
#  '2017-05-12_5_4C-70per_3C_CH17' '2017-05-12_5_4C-70per_3C_CH18'
#  '2017-05-12_6C-40per_3C_CH25' '2017-05-12_6C-40per_3C_CH26'
#  '2017-05-12_6C-50per_3C_CH27' '2017-05-12_6C-50per_3C_CH28'
#  '2017-05-12_6C-60per_3C_CH29' '2017-05-12_6C-60per_3C_CH30'
#  '2017-05-12_7C-40per_3C_CH37' '2017-05-12_7C-40per_3C_CH38'
#  '2017-05-12_4C-80per_4C_CH5' '2017-05-12_4C-80per_4C_CH6'
#  '2017-05-12_4_4C-80per_4_4C_CH7' '2017-05-12_5_4C-80per_5_4C_CH11'
#  '2017-05-12_5_4C-80per_5_4C_CH12' '2017-05-12_3_6C-80per_3_6C_CH1'
#  '2017-05-12_3_6C-80per_3_6C_CH2' '2017-05-12_3_6C-80per_3_6C_CH3'
#  '2017-05-12_5_4C-40per_3_6C_CH19']

# %%
# Get the cell-ID from cell_inventory
selected_cell_label = "2017-05-12_5_4C-70per_3C_CH17"

# Create a subfolder to store fig output
# corresponding to each cell-index
selected_cell_artifacts_dir = bconf.artifacts_output_dir(
    selected_cell_label)

# %% [markdown]
# ## Drop true labels
#
# * Drop true outlier labels (denoted as ``outlier``) from the dataframe and select only relevant features for ML:
#   * ``cell_index``: The cell-ID for data and model versioning purposes;
#   * ``cycle_index``: The cycle number of each cell;
#   * ``discharge_capacity``: Discharge capacity of the cell;
#   * ``voltage``: Discharge voltage of the cell.

# %%
# Import the BenchDB class
# Load only the dataset based on the selected cell
benchdb = BenchDB(
    db_filepath,
    selected_cell_label)

# load the benchmarking dataset
df_selected_cell = benchdb.load_benchmark_dataset(
    dataset_type="train")

if df_selected_cell is not None:

    filter_col = [
        "cell_index",
        "cycle_index",
        "discharge_capacity",
        "voltage"]

    # Drop true labels from the benchmarking dataset
    # and filter for selected columns only
    df_selected_cell_without_labels = benchdb.drop_labels(
        df_selected_cell,
        filter_col)
# Out:
# Database is found in the given filepath.
# Loading benchmarking dataset now...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ****************************************************************************************************

# %% [markdown]
# ## Plot cycling data without labels

# %%
# If the true outlier cycle index is not known,
# cycling data will be plotted without labels
benchdb.plot_cycle_data(
    df_selected_cell_without_labels)

plt.show()

# %% [markdown]
# # Statistical Feature Transformation
#
# To help with the separation of abnormal cycles from normal cycles, we propose a new statistical feature transformation method using the median and IQR of the input features:
#
# $$
# \begin{equation}
# x_\textrm{scaled} = x_i - \left[\frac{\textrm{median}(X)^{2}}{\textrm{IQR}(X)}\right],
# \end{equation}
# $$
#
# where the IQR can be calculated from the third ($75^\textrm{th}$ percentile) and first quartile ($25^\textrm{th}$ percentile) of the input vector ($\textrm{IQR}(X) = Q_3(X) - Q_1(X)$). Here, we use $\textrm{median}(X)^2$ to preserve the physical unit of the original feature after feature transformation. Feature scaling is implemented on both the capacity and voltage data.
#
# ## Capacity scaling

# %%
# Instantiate the CycleScaling class
scaler = CycleScaling(
    df_selected_cell=df_selected_cell_without_labels)

# Implement median IQR scaling on the discharge capacity data
df_capacity_med_scaled = scaler.median_IQR_scaling(
    variable="discharge_capacity",
    validate=True)

# Plot the histogram and boxplot of the scaled data
ax_hist = bviz.hist_boxplot(
    df_variable=df_capacity_med_scaled["scaled_discharge_capacity"])

ax_hist.set_xlabel(
    r"Discharge capacity, $Q_\textrm{dis}$ [Ah]",
    fontsize=12)
ax_hist.set_ylabel(
    r"Count",
    fontsize=12)

output_fig_filename = (
    "cap_scaling_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# Print the summary statistics of the scaled capacity data
print(df_capacity_med_scaled["scaled_discharge_capacity"].describe())
print("*"*70)

df_capacity_med_scaled["scaled_discharge_capacity"]
# Out:
# count    313326.000000
# mean         -0.349626
# std           0.414280
# min          -2.933561
# 25%          -0.677412
# 50%          -0.226724
# 75%           0.005721
# max           0.844670
# Name: scaled_discharge_capacity, dtype: float64
# **********************************************************************
# 0        -0.828787
# 1        -0.827432
# 2        -0.825870
# 3        -0.824306
# 4        -0.824306
#             ...
# 301553   -0.145985
# 301554   -0.145915
# 301555   -0.145915
# 301556   -0.145867
# 301557   -0.145867
# Name: scaled_discharge_capacity, Length: 313326, dtype: float64

# %% [markdown]
# ## Voltage scaling

# %%
# Implement median IQR scaling on the discharge voltage data
df_voltage_med_scaled = scaler.median_IQR_scaling(
    variable="voltage",
    validate=True)

# Plot the histogram and boxplot of the scaled data
ax_hist = bviz.hist_boxplot(
    df_variable=df_voltage_med_scaled["scaled_voltage"])

ax_hist.set_xlabel(
    r"Scaled voltage, $V_\textrm{dis}$ [V]",
    fontsize=12)
ax_hist.set_ylabel(
    r"Count",
    fontsize=12)

output_fig_filename = (
    "voltage_scaling_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# Print the summary statistics of the scaled capacity data
print(df_voltage_med_scaled["scaled_voltage"].describe())
print("*"*70)
df_voltage_med_scaled["scaled_voltage"]
# Out:
# count    313326.000000
# mean         -6.557421
# std           7.159671
# min         -45.644671
# 25%          -5.844655
# 50%          -5.215267
# 75%          -4.672330
# max          -2.395836
# Name: scaled_voltage, dtype: float64
# **********************************************************************
# 0        -12.262836
# 1        -12.272870
# 2        -12.276842
# 3        -12.279593
# 4        -12.279593
#             ...
# 301553    -4.257652
# 301554    -4.257553
# 301555    -4.257553
# 301556    -4.257912
# 301557    -4.254364
# Name: scaled_voltage, Length: 313326, dtype: float64

# %% [markdown]
# ## Scatter histogram
#
# * Create scatterplot with histogram to display the distribution for x-axis and y-axis:
#   * The salmon color corresponds to x-axis (``scaled_capacity``)
#   * The grey color corresponds to y-axis (``scaled_voltage``)

# %%
axplot = bviz.scatterhist(
    xseries=df_selected_cell_without_labels["discharge_capacity"],
    yseries=df_selected_cell_without_labels["voltage"],
    cycle_index_series=df_selected_cell_without_labels["cycle_index"],
    selected_cell_label=selected_cell_label)

axplot.set_xlabel(
    r"Capacity, $Q_\textrm{dis}$ [Ah]",
    fontsize=12)
axplot.set_ylabel(
    r"Voltage, $V_\textrm{dis}$ [V]",
    fontsize=12)

output_fig_filename = (
    "scatterhist_no_scaling_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %%
axplot = bviz.scatterhist(
    xseries=df_capacity_med_scaled["scaled_discharge_capacity"],
    yseries=df_voltage_med_scaled["scaled_voltage"],
    cycle_index_series=df_selected_cell_without_labels["cycle_index"])

axplot.set_xlabel(
    r"Scaled capacity, $Q_\textrm{dis}$ [Ah]",
    fontsize=12)
axplot.set_ylabel(
    r"Scaled voltage, $V_\textrm{dis}$ [V]",
    fontsize=12)

output_fig_filename = (
    "scatterhist_with_scaling_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Physics-informed Feature Extraction
#
# * As the anomalies in this dataset are collective due to a continuous series of abnormal voltage and current measurements, we can transform the collective anomalies of a given cycle into cycle-wise point anomalies.
# * Use $\Delta V$ to detect any anomalies in the voltage data
# * Because our focus is on detecting anomalous cycle (multiple collective outliers and not a single data point), we are only interested in the maximum $\Delta V$ per cycle.
# * Drop the first and last 10 data points to exclude instantaneous voltage jump due to voltage relaxation at the beginning and at the end because of current interruptions. These are normal voltage behaviour, not considered as anomaly.
# * If continuous abnormal voltage and current measurements are recorded in a cycle, the specific cycle will be labelled as anomalous cycle.
#
# $$
# \begin{align}
# \Delta Q_\textrm{scaled,max,cyc} &= \underset{\textrm{cyc}}{\max}(Q_{\textrm{scaled},{k+1}} - Q_{\textrm{scaled},{k}}), \\
# \Delta V_\textrm{scaled,max,cyc} &= \underset{\textrm{cyc}}{\max}(V_{\textrm{scaled},{k+1}} - V_{\textrm{scaled},{k}}),
# \end{align}
# $$
#
# where $\Delta V_\textrm{scaled,max,cyc}$ is the maximum scaled voltage difference per cycle and $\Delta Q_\textrm{scaled,max,cyc}$ is the maximum scaled capacity difference per cycle. $k$ in these equations denote the index of each recorded data point.
#
# * Don't use the natural index of the dataframe as the cycle index
# * Create an additional column for the cycle_index so that we can keep track of the true cycle_index even after removing some anomalous cycle from the df

# %% [markdown]
# ## Feature max dV

# %%
# maximum scaled voltage difference per cycle
df_max_dV = scaler.calculate_max_diff_per_cycle(
    df_scaled=df_voltage_med_scaled,
    variable_name="scaled_voltage")

df_max_dV
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>max_diff</th>
#       <th>log_max_diff</th>
#       <th>cycle_index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.564151</td>
#       <td>0.447343</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.023727</td>
#       <td>-3.741163</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.022684</td>
#       <td>-3.786091</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.027899</td>
#       <td>-3.579172</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.026408</td>
#       <td>-3.634081</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>687</th>
#       <td>0.046420</td>
#       <td>-3.070023</td>
#       <td>687.0</td>
#     </tr>
#     <tr>
#       <th>688</th>
#       <td>0.051542</td>
#       <td>-2.965352</td>
#       <td>688.0</td>
#     </tr>
#     <tr>
#       <th>689</th>
#       <td>0.047776</td>
#       <td>-3.041228</td>
#       <td>689.0</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>0.046331</td>
#       <td>-3.071935</td>
#       <td>690.0</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>0.047873</td>
#       <td>-3.039193</td>
#       <td>691.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>692 rows x 3 columns</p>
# </div>

# %%
max_dV_feature_stats = bstats.calculate_feature_stats(
    df_max_dV["max_diff"],
    new_col_name="max_diff_dV")

max_dV_feature_stats
# Out:
# Feature mean: 0.04105323627167629
# Feature max: 2.612268400000005
# Feature min: 0.022684100000000207
# Feature std: 0.11397361246602544
# **********************************************************************
#       max_diff_dV
# max        2.6123
# min        0.0227
# mean       0.0411
# std        0.1140

# %% [markdown]
# ## Feature max dQ

# %%
# maximum scaled capacity difference per cycle
df_max_dQ = scaler.calculate_max_diff_per_cycle(
    df_scaled=df_capacity_med_scaled,
    variable_name="scaled_discharge_capacity")

df_max_dQ
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>max_diff</th>
#       <th>log_max_diff</th>
#       <th>cycle_index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.006388</td>
#       <td>-5.053343</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.006338</td>
#       <td>-5.061258</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.006321</td>
#       <td>-5.063922</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.006259</td>
#       <td>-5.073756</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.006236</td>
#       <td>-5.077346</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>687</th>
#       <td>0.006236</td>
#       <td>-5.077391</td>
#       <td>687.0</td>
#     </tr>
#     <tr>
#       <th>688</th>
#       <td>0.006281</td>
#       <td>-5.070178</td>
#       <td>688.0</td>
#     </tr>
#     <tr>
#       <th>689</th>
#       <td>0.006243</td>
#       <td>-5.076238</td>
#       <td>689.0</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>0.006316</td>
#       <td>-5.064619</td>
#       <td>690.0</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>0.006402</td>
#       <td>-5.051123</td>
#       <td>691.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>692 rows x 3 columns</p>
# </div>

# %%
max_dQ_feature_stats = bstats.calculate_feature_stats(
    df_max_dQ["max_diff"],
    new_col_name="max_diff_dQ")

max_dQ_feature_stats
# Out:
# Feature mean: 0.00641125672398844
# Feature max: 0.042899057000000074
# Feature min: 0.006194469999999952
# Feature std: 0.0019646872892444154
# **********************************************************************
#       max_diff_dQ
# max        0.0429
# min        0.0062
# mean       0.0064
# std        0.0020

# %% [markdown]
# ## Feature max dVdQ

# %%
df_max_dVdQ = scaler.calculate_max_feature_derivative_per_cycle(
    Xfeature=df_capacity_med_scaled["scaled_discharge_capacity"],
    Yfeature=df_voltage_med_scaled["scaled_voltage"],
    cycle_index=df_voltage_med_scaled["cycle_index"])

df_max_dVdQ
# Out:
# /home/mei-chin-pang/02_academics/osbad_development/osbad/src/osbad/scaler.py:262: RuntimeWarning: divide by zero encountered in divide
#   feature_diff = numerator_feature_diff/denominator_feature_diff
# /home/mei-chin-pang/02_academics/osbad_development/osbad/src/osbad/scaler.py:262: RuntimeWarning: invalid value encountered in divide
#   feature_diff = numerator_feature_diff/denominator_feature_diff
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>max_diff</th>
#       <th>log_max_diff</th>
#       <th>cycle_index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>178932.163746</td>
#       <td>12.094762</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.879725</td>
#       <td>2.386901</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9.355405</td>
#       <td>2.235954</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7.779197</td>
#       <td>2.051453</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9.119772</td>
#       <td>2.210445</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>687</th>
#       <td>8.897922</td>
#       <td>2.185818</td>
#       <td>687.0</td>
#     </tr>
#     <tr>
#       <th>688</th>
#       <td>7.007765</td>
#       <td>1.947019</td>
#       <td>688.0</td>
#     </tr>
#     <tr>
#       <th>689</th>
#       <td>7.087613</td>
#       <td>1.958349</td>
#       <td>689.0</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>7.316459</td>
#       <td>1.990126</td>
#       <td>690.0</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>54.619562</td>
#       <td>4.000392</td>
#       <td>691.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>692 rows x 3 columns</p>
# </div>

# %%
max_dVdQ_feature_stats = bstats.calculate_feature_stats(
    df_max_dVdQ["max_diff"],
    new_col_name="max_diff_dVdQ")

max_dVdQ_feature_stats
# Out:
# Feature mean: 321.2474799595722
# Feature max: 178932.16374587023
# Feature min: 4.1214299224441175
# Feature std: 6918.580867088767
# **********************************************************************
#       max_diff_dVdQ
# max     178932.1637
# min          4.1214
# mean       321.2475
# std       6918.5809

# %% [markdown]
# # IQR method
#
# $$
# \begin{equation}
# IQR = Q_3 - Q_1.
# \end{equation}
# $$
#
# * The first quartile ($Q_1$) is the median of the lower half of the dataset ($25^\textrm{th}$ percentile)
# * The third quartile ($Q_3$) is the median of the upper half of the dataset ($75^\textrm{th}$ percentile).
# * IQR is usually visualized using boxplot, where the data distribution can be described based on a five number summary (minimum, Q1, median, Q3 and maximum).
# * Measurements are denoted as outliers if they fall outside the lower and upper bound:
#
# $$
# \begin{align}
# IQR_\textrm{lower} &= Q_1 - (1.5 \times IQR), \nonumber \\
# IQR_\textrm{upper} &= Q_3 + (1.5 \times IQR),
# \end{align}
# $$

# %% [markdown]
# # Feature: dV
#
# ## IQR on dV

# %%
# Access the dict of parameters for using 
# the IQR method
iqr_param_dict = bstats.outlier_method["iqr"].params
print(iqr_param_dict)
# Out:
# {'iqr_threshold': 1.5}

# %%
(IQR_outlier_index_dV,
 IQR_min_limit_dV,
 IQR_max_limit_dV) = bstats.outlier_method["iqr"].compute(
    df_max_dV["max_diff"], 
    **iqr_param_dict)

print("*"*70)
print(f"IQR outlier index on dV: {IQR_outlier_index_dV}")
print(df_max_dV[df_max_dV["cycle_index"].isin(IQR_outlier_index_dV)])
print("*"*70)
# Out:
# IQR lower limit: 0.020640312500000757
# IQR upper limit: 0.04860141249999961
# **********************************************************************
# IQR outlier index on dV: [  0  40 628 641 642 643 647 651 652 654 657 663 665 667 681 683 688]
#      max_diff  log_max_diff  cycle_index
# 0    1.564151      0.447343          0.0
# 40   2.612268      0.960219         40.0
# 628  0.048703     -3.022011        628.0
# 641  0.049953     -2.996663        641.0
# 642  0.048806     -3.019898        642.0
# 643  0.049055     -3.014811        643.0
# 647  0.049023     -3.015472        647.0
# 651  0.049693     -3.001889        651.0
# 652  0.049136     -3.013159        652.0
# 654  0.049086     -3.014190        654.0
# 657  0.050223     -2.991276        657.0
# 663  0.048631     -3.023500        663.0
# 665  0.050672     -2.982372        665.0
# 667  0.048630     -3.023521        667.0
# 681  0.051587     -2.964484        681.0
# 683  0.049715     -3.001447        683.0
# 688  0.051542     -2.965352        688.0
# **********************************************************************

# %% [markdown]
# ### Bubble plot

# %%
unique_cycle_count = (
    df_selected_cell_without_labels["cycle_index"]
    .unique())

df_bubble_size_dV = bviz.calculate_bubble_size_ratio(
    df_variable=df_max_dV["max_diff"])

# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=unique_cycle_count,
    yseries=df_max_dV["max_diff"],
    bubble_size=df_bubble_size_dV,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=IQR_outlier_index_dV)

axplot.set_xlabel(
    r"Cycle number, $N_\textrm{cyc}$ [-]",
    fontsize=12)

axplot.set_ylabel(
    r"$\Delta V_\textrm{scaled,max,cyc}\;\textrm{[V]}$",
    fontsize=12)

fig_title=(r"IQR on $\Delta V_\textrm{scaled,max,cyc}$")

axplot.set_title(
    fig_title,
    fontsize=16)

output_fig_filename = (
    "iqr_dv_bubble_plot_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Feature mean: 0.04105323627167629
# Feature max: 2.612268400000005
# Feature min: 0.022684100000000207
# Feature std: 0.11397361246602544
# **********************************************************************
# Potential anomalous cycle: 0.0
# x-position of the text: 0.0
# y-position of the text: 1.5641508000000002
# ----------------------------------------------------------------------
# Potential anomalous cycle: 40.0
# x-position of the text: 40.0
# y-position of the text: 2.612268400000005
# ----------------------------------------------------------------------
# Potential anomalous cycle: 628.0
# x-position of the text: 628.0
# y-position of the text: 0.04870320000000028
# ----------------------------------------------------------------------
# Potential anomalous cycle: 641.0
# x-position of the text: 641.0
# y-position of the text: 0.049953499999999096
# ----------------------------------------------------------------------
# Potential anomalous cycle: 642.0
# x-position of the text: 642.0
# y-position of the text: 0.048806200000000466
# ----------------------------------------------------------------------
# Potential anomalous cycle: 643.0
# x-position of the text: 643.0
# y-position of the text: 0.04905510000000035
# ----------------------------------------------------------------------
# Potential anomalous cycle: 647.0
# x-position of the text: 647.0
# y-position of the text: 0.049022700000000086
# ----------------------------------------------------------------------
# Potential anomalous cycle: 651.0
# x-position of the text: 651.0
# y-position of the text: 0.049693099999999824
# ----------------------------------------------------------------------
# Potential anomalous cycle: 652.0
# x-position of the text: 652.0
# y-position of the text: 0.04913619999999952
# ----------------------------------------------------------------------
# Potential anomalous cycle: 654.0
# x-position of the text: 654.0
# y-position of the text: 0.04908560000000062
# ----------------------------------------------------------------------
# Potential anomalous cycle: 657.0
# x-position of the text: 657.0
# y-position of the text: 0.05022330000000075
# ----------------------------------------------------------------------
# Potential anomalous cycle: 663.0
# x-position of the text: 663.0
# y-position of the text: 0.04863069999999947
# ----------------------------------------------------------------------
# Potential anomalous cycle: 665.0
# x-position of the text: 665.0
# y-position of the text: 0.05067249999999923
# ----------------------------------------------------------------------
# Potential anomalous cycle: 667.0
# x-position of the text: 667.0
# y-position of the text: 0.04862970000000022
# ----------------------------------------------------------------------
# Potential anomalous cycle: 681.0
# x-position of the text: 681.0
# y-position of the text: 0.051587100000000774
# ----------------------------------------------------------------------
# Potential anomalous cycle: 683.0
# x-position of the text: 683.0
# y-position of the text: 0.049715100000000234
# ----------------------------------------------------------------------
# Potential anomalous cycle: 688.0
# x-position of the text: 688.0
# y-position of the text: 0.051542299999999486
# ----------------------------------------------------------------------

# %% [markdown]
# ### Confusion matrix

# %%
# Compare IQR predicted anomalies with true anomalies
df_eval_outlier_iqr_dV = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=IQR_outlier_index_dV)

# Generate custom confusion matrix
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier_iqr_dV["true_outlier"],
    y_pred=df_eval_outlier_iqr_dV["pred_outlier"])

fig_title=(r"IQR on $\Delta V_\textrm{scaled,max,cyc}$ \newline")

axplot.set_title(
    fig_title 
    + "\n",
    fontsize=16)

output_fig_filename = (
    "iqr_conf_matrix_dv_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Feature: dQ
#
# ## IQR on dQ

# %%
(IQR_outlier_index_dQ,
 IQR_min_limit_dQ,
 IQR_max_limit_dQ) = bstats.outlier_method["iqr"].compute(
    df_max_dQ["max_diff"], 
    **iqr_param_dict)

print("*"*70)
print(f"IQR outlier index on dQ: {IQR_outlier_index_dQ}")
print(df_max_dQ[df_max_dQ["cycle_index"].isin(IQR_outlier_index_dQ)])
print("*"*70)
# Out:
# IQR lower limit: 0.00615791874999988
# IQR upper limit: 0.006439588750000003
# **********************************************************************
# IQR outlier index on dQ: [  7  15  16  23  26  32  34  39  70 136 144 147 148 222 227 240 268 305
#  321 324 356 369 418 448 505 538 685]
#      max_diff  log_max_diff  cycle_index
# 7    0.006440     -5.045193          7.0
# 15   0.006524     -5.032257         15.0
# 16   0.006556     -5.027451         16.0
# 23   0.006594     -5.021527         23.0
# 26   0.006467     -5.041082         26.0
# 32   0.006912     -4.974528         32.0
# 34   0.006456     -5.042714         34.0
# 39   0.006468     -5.040963         39.0
# 70   0.006490     -5.037430         70.0
# 136  0.006497     -5.036365        136.0
# 144  0.006485     -5.038316        144.0
# 147  0.042814     -3.150895        147.0
# 148  0.042899     -3.148905        148.0
# 222  0.006462     -5.041892        222.0
# 227  0.006590     -5.022164        227.0
# 240  0.006523     -5.032447        240.0
# 268  0.006565     -5.026038        268.0
# 305  0.006454     -5.043131        305.0
# 321  0.006508     -5.034660        321.0
# 324  0.006564     -5.026175        324.0
# 356  0.006454     -5.043106        356.0
# 369  0.006469     -5.040723        369.0
# 418  0.006460     -5.042169        418.0
# 448  0.006467     -5.041117        448.0
# 505  0.006447     -5.044207        505.0
# 538  0.006503     -5.035436        538.0
# 685  0.006664     -5.011083        685.0
# **********************************************************************

# %% [markdown]
# ### Bubble plot

# %%
unique_cycle_count = (
    df_selected_cell_without_labels["cycle_index"]
    .unique())

df_bubble_size_dQ = bviz.calculate_bubble_size_ratio(
    df_variable=df_max_dQ["max_diff"])

# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=unique_cycle_count,
    yseries=df_max_dQ["max_diff"],
    bubble_size=df_bubble_size_dQ,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=IQR_outlier_index_dQ)

axplot.set_xlabel(
    r"Cycle number, $N_\textrm{cyc}$ [-]",
    fontsize=12)

axplot.set_ylabel(
    r"$\Delta Q_\textrm{scaled,max,cyc}\;\textrm{[V]}$",
    fontsize=12)

fig_title=(r"IQR on $\Delta Q_\textrm{scaled,max,cyc}$")

axplot.set_title(
    fig_title,
    fontsize=16)

output_fig_filename = (
    "iqr_dq_bubble_plot_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Feature mean: 0.00641125672398844
# Feature max: 0.042899057000000074
# Feature min: 0.006194469999999952
# Feature std: 0.0019646872892444154
# **********************************************************************
# Potential anomalous cycle: 7.0
# x-position of the text: 7.0
# y-position of the text: 0.0064402199999999965
# ----------------------------------------------------------------------
# Potential anomalous cycle: 15.0
# x-position of the text: 15.0
# y-position of the text: 0.006524070000000104
# ----------------------------------------------------------------------
# Potential anomalous cycle: 16.0
# x-position of the text: 16.0
# y-position of the text: 0.006555500000000047
# ----------------------------------------------------------------------
# Potential anomalous cycle: 23.0
# x-position of the text: 23.0
# y-position of the text: 0.006594449999999918
# ----------------------------------------------------------------------
# Potential anomalous cycle: 26.0
# x-position of the text: 26.0
# y-position of the text: 0.006466750000000077
# ----------------------------------------------------------------------
# Potential anomalous cycle: 32.0
# x-position of the text: 32.0
# y-position of the text: 0.006911780000000034
# ----------------------------------------------------------------------
# Potential anomalous cycle: 34.0
# x-position of the text: 34.0
# y-position of the text: 0.006456200000000023
# ----------------------------------------------------------------------
# Potential anomalous cycle: 39.0
# x-position of the text: 39.0
# y-position of the text: 0.006467519999999949
# ----------------------------------------------------------------------
# Potential anomalous cycle: 70.0
# x-position of the text: 70.0
# y-position of the text: 0.0064904100000000575
# ----------------------------------------------------------------------
# Potential anomalous cycle: 136.0
# x-position of the text: 136.0
# y-position of the text: 0.006497320000000029
# ----------------------------------------------------------------------
# Potential anomalous cycle: 144.0
# x-position of the text: 144.0
# y-position of the text: 0.0064846599999999754
# ----------------------------------------------------------------------
# Potential anomalous cycle: 147.0
# x-position of the text: 147.0
# y-position of the text: 0.04281378999999996
# ----------------------------------------------------------------------
# Potential anomalous cycle: 148.0
# x-position of the text: 148.0
# y-position of the text: 0.042899057000000074
# ----------------------------------------------------------------------
# Potential anomalous cycle: 222.0
# x-position of the text: 222.0
# y-position of the text: 0.006461510000000059
# ----------------------------------------------------------------------
# Potential anomalous cycle: 227.0
# x-position of the text: 227.0
# y-position of the text: 0.00659025000000002
# ----------------------------------------------------------------------
# Potential anomalous cycle: 240.0
# x-position of the text: 240.0
# y-position of the text: 0.0065228299999999795
# ----------------------------------------------------------------------
# Potential anomalous cycle: 268.0
# x-position of the text: 268.0
# y-position of the text: 0.0065647699999999976
# ----------------------------------------------------------------------
# Potential anomalous cycle: 305.0
# x-position of the text: 305.0
# y-position of the text: 0.00645350999999994
# ----------------------------------------------------------------------
# Potential anomalous cycle: 321.0
# x-position of the text: 321.0
# y-position of the text: 0.00650841000000002
# ----------------------------------------------------------------------
# Potential anomalous cycle: 324.0
# x-position of the text: 324.0
# y-position of the text: 0.006563870000000027
# ----------------------------------------------------------------------
# Potential anomalous cycle: 356.0
# x-position of the text: 356.0
# y-position of the text: 0.006453669999999967
# ----------------------------------------------------------------------
# Potential anomalous cycle: 369.0
# x-position of the text: 369.0
# y-position of the text: 0.006469070000000077
# ----------------------------------------------------------------------
# Potential anomalous cycle: 418.0
# x-position of the text: 418.0
# y-position of the text: 0.006459719999999947
# ----------------------------------------------------------------------
# Potential anomalous cycle: 448.0
# x-position of the text: 448.0
# y-position of the text: 0.00646651999999992
# ----------------------------------------------------------------------
# Potential anomalous cycle: 505.0
# x-position of the text: 505.0
# y-position of the text: 0.00644657000000004
# ----------------------------------------------------------------------
# Potential anomalous cycle: 538.0
# x-position of the text: 538.0
# y-position of the text: 0.006503360000000069
# ----------------------------------------------------------------------
# Potential anomalous cycle: 685.0
# x-position of the text: 685.0
# y-position of the text: 0.006663680000000061
# ----------------------------------------------------------------------

# %% [markdown]
# ### Confusion matrix

# %%
# Compare IQR predicted anomalies with true anomalies
df_eval_outlier_iqr_dQ = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=IQR_outlier_index_dQ)

# Generate custom confusion matrix
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier_iqr_dQ["true_outlier"],
    y_pred=df_eval_outlier_iqr_dQ["pred_outlier"])

fig_title=(r"IQR on $\Delta Q_\textrm{scaled,max,cyc}$ \newline")

axplot.set_title(
    fig_title 
    + "\n",
    fontsize=16)

output_fig_filename = (
    "iqr_conf_matrix_dq_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Feature: dVdQ
#
# ## IQR on log(dVdQ)

# %%
(IQR_outlier_index_dVdQ,
 IQR_min_limit_dVdQ,
 IQR_max_limit_dVdQ) = bstats.outlier_method["iqr"].compute(
    df_max_dVdQ["log_max_diff"], 
    **iqr_param_dict)

print("*"*70)
print(f"IQR outlier index on dVdQ: {IQR_outlier_index_dVdQ}")
print(df_max_dVdQ[df_max_dVdQ["cycle_index"].isin(IQR_outlier_index_dVdQ)])
print("*"*70)
# Out:
# IQR lower limit: 1.507846654111778
# IQR upper limit: 3.4634069217571612
# **********************************************************************
# IQR outlier index on dVdQ: [  0  33  34  40 105 141 249 280 320 338 339 476 497 548 555 557 566 567
#  569 572 574 581 587 592 603 617 637 643 648 656 660 666 670 671 677 680
#  691]
#           max_diff  log_max_diff  cycle_index
# 0    178932.163746     12.094762          0.0
# 33       32.156096      3.470602         33.0
# 34       36.818579      3.606003         34.0
# 40    33622.153846     10.422940         40.0
# 105      34.429071      3.538901        105.0
# 141      33.819155      3.521027        141.0
# 249      32.607388      3.484539        249.0
# 280      39.508087      3.676505        280.0
# 320      39.395457      3.673651        320.0
# 338      35.666291      3.574206        338.0
# 339      33.351721      3.507109        339.0
# 476      32.454076      3.479826        476.0
# 497      32.786561      3.490019        497.0
# 548      35.745237      3.576417        548.0
# 555      31.980567      3.465128        555.0
# 557      37.104062      3.613726        557.0
# 566      33.055738      3.498195        566.0
# 567      33.458829      3.510316        567.0
# 569      32.963772      3.495409        569.0
# 572      35.718238      3.575661        572.0
# 574      34.291911      3.534909        574.0
# 581      40.493875      3.701151        581.0
# 587      34.953198      3.554010        587.0
# 592      33.850874      3.521965        592.0
# 603      32.144168      3.470231        603.0
# 617      36.361974      3.593524        617.0
# 637       4.121430      1.416200        637.0
# 643      47.517896      3.861106        643.0
# 648       4.495357      1.503045        648.0
# 656       4.398315      1.481222        656.0
# 660      37.861078      3.633924        660.0
# 666      39.705270      3.681484        666.0
# 670      34.766657      3.548659        670.0
# 671      38.217407      3.643291        671.0
# 677      40.479587      3.700798        677.0
# 680      46.619760      3.842024        680.0
# 691      54.619562      4.000392        691.0
# **********************************************************************

# %% [markdown]
# ### Bubble plot

# %%
unique_cycle_count = (
    df_selected_cell_without_labels["cycle_index"]
    .unique())

df_bubble_size_dVdQ = bviz.calculate_bubble_size_ratio(
    df_variable=df_max_dVdQ["max_diff"])

# Plot the bubble chart and label the outliers
axplot = bviz.plot_bubble_chart(
    xseries=unique_cycle_count,
    yseries=df_max_dVdQ["max_diff"],
    bubble_size=df_bubble_size_dVdQ,
    unique_cycle_count=unique_cycle_count,
    cycle_outlier_idx_label=IQR_outlier_index_dVdQ)

axplot.set_xlabel(
    r"Cycle number, $N_\textrm{cyc}$ [-]",
    fontsize=12)

axplot.set_ylabel(
    r"$(d\textrm{V}d\textrm{Q})_\textrm{scaled,max,cyc}\;\textrm{[V Ah$^{-1}$]}$",
    fontsize=12)

fig_title=(r"IQR on $d\textrm{V}d\textrm{Q}_\textrm{scaled,max,cyc}$ \newline")

axplot.set_title(
    fig_title,
    fontsize=16)

output_fig_filename = (
    "iqr_dvdq_bubble_plot_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()
# Out:
# Feature mean: 321.2474799595722
# Feature max: 178932.16374587023
# Feature min: 4.1214299224441175
# Feature std: 6918.580867088767
# **********************************************************************
# Potential anomalous cycle: 0.0
# x-position of the text: 0.0
# y-position of the text: 178932.16374587023
# ----------------------------------------------------------------------
# Potential anomalous cycle: 33.0
# x-position of the text: 33.0
# y-position of the text: 32.15609587263099
# ----------------------------------------------------------------------
# Potential anomalous cycle: 34.0
# x-position of the text: 34.0
# y-position of the text: 36.81857900759628
# ----------------------------------------------------------------------
# Potential anomalous cycle: 40.0
# x-position of the text: 40.0
# y-position of the text: 33622.15384614415
# ----------------------------------------------------------------------
# Potential anomalous cycle: 105.0
# x-position of the text: 105.0
# y-position of the text: 34.429070783570126
# ----------------------------------------------------------------------
# Potential anomalous cycle: 141.0
# x-position of the text: 141.0
# y-position of the text: 33.81915477497521
# ----------------------------------------------------------------------
# Potential anomalous cycle: 249.0
# x-position of the text: 249.0
# y-position of the text: 32.60738795221823
# ----------------------------------------------------------------------
# Potential anomalous cycle: 280.0
# x-position of the text: 280.0
# y-position of the text: 39.50808743169386
# ----------------------------------------------------------------------
# Potential anomalous cycle: 320.0
# x-position of the text: 320.0
# y-position of the text: 39.39545709594784
# ----------------------------------------------------------------------
# Potential anomalous cycle: 338.0
# x-position of the text: 338.0
# y-position of the text: 35.66629129128983
# ----------------------------------------------------------------------
# Potential anomalous cycle: 339.0
# x-position of the text: 339.0
# y-position of the text: 33.35172119672332
# ----------------------------------------------------------------------
# Potential anomalous cycle: 476.0
# x-position of the text: 476.0
# y-position of the text: 32.45407550608314
# ----------------------------------------------------------------------
# Potential anomalous cycle: 497.0
# x-position of the text: 497.0
# y-position of the text: 32.7865609093682
# ----------------------------------------------------------------------
# Potential anomalous cycle: 548.0
# x-position of the text: 548.0
# y-position of the text: 35.74523729946547
# ----------------------------------------------------------------------
# Potential anomalous cycle: 555.0
# x-position of the text: 555.0
# y-position of the text: 31.98056745973184
# ----------------------------------------------------------------------
# Potential anomalous cycle: 557.0
# x-position of the text: 557.0
# y-position of the text: 37.1040619093457
# ----------------------------------------------------------------------
# Potential anomalous cycle: 566.0
# x-position of the text: 566.0
# y-position of the text: 33.05573787940648
# ----------------------------------------------------------------------
# Potential anomalous cycle: 567.0
# x-position of the text: 567.0
# y-position of the text: 33.458828570069144
# ----------------------------------------------------------------------
# Potential anomalous cycle: 569.0
# x-position of the text: 569.0
# y-position of the text: 32.963772282922136
# ----------------------------------------------------------------------
# Potential anomalous cycle: 572.0
# x-position of the text: 572.0
# y-position of the text: 35.71823755387194
# ----------------------------------------------------------------------
# Potential anomalous cycle: 574.0
# x-position of the text: 574.0
# y-position of the text: 34.29191096733795
# ----------------------------------------------------------------------
# Potential anomalous cycle: 581.0
# x-position of the text: 581.0
# y-position of the text: 40.493874803680015
# ----------------------------------------------------------------------
# Potential anomalous cycle: 587.0
# x-position of the text: 587.0
# y-position of the text: 34.95319793112002
# ----------------------------------------------------------------------
# Potential anomalous cycle: 592.0
# x-position of the text: 592.0
# y-position of the text: 33.850873978371936
# ----------------------------------------------------------------------
# Potential anomalous cycle: 603.0
# x-position of the text: 603.0
# y-position of the text: 32.144168139252066
# ----------------------------------------------------------------------
# Potential anomalous cycle: 617.0
# x-position of the text: 617.0
# y-position of the text: 36.361974237040364
# ----------------------------------------------------------------------
# Potential anomalous cycle: 637.0
# x-position of the text: 637.0
# y-position of the text: 4.1214299224441175
# ----------------------------------------------------------------------
# Potential anomalous cycle: 643.0
# x-position of the text: 643.0
# y-position of the text: 47.51789606238158
# ----------------------------------------------------------------------
# Potential anomalous cycle: 648.0
# x-position of the text: 648.0
# y-position of the text: 4.49535657962787
# ----------------------------------------------------------------------
# Potential anomalous cycle: 656.0
# x-position of the text: 656.0
# y-position of the text: 4.398315282789142
# ----------------------------------------------------------------------
# Potential anomalous cycle: 660.0
# x-position of the text: 660.0
# y-position of the text: 37.8610778228919
# ----------------------------------------------------------------------
# Potential anomalous cycle: 666.0
# x-position of the text: 666.0
# y-position of the text: 39.70527037077301
# ----------------------------------------------------------------------
# Potential anomalous cycle: 670.0
# x-position of the text: 670.0
# y-position of the text: 34.76665665622615
# ----------------------------------------------------------------------
# Potential anomalous cycle: 671.0
# x-position of the text: 671.0
# y-position of the text: 38.21740732940072
# ----------------------------------------------------------------------
# Potential anomalous cycle: 677.0
# x-position of the text: 677.0
# y-position of the text: 40.47958652555226
# ----------------------------------------------------------------------
# Potential anomalous cycle: 680.0
# x-position of the text: 680.0
# y-position of the text: 46.61975986075309
# ----------------------------------------------------------------------
# Potential anomalous cycle: 691.0
# x-position of the text: 691.0
# y-position of the text: 54.619562117079795
# ----------------------------------------------------------------------

# %% [markdown]
# ### Confusion matrix

# %%
# Compare IQR predicted anomalies with true anomalies
df_eval_outlier_iqr_dVdQ = modval.evaluate_pred_outliers(
    df_benchmark=df_selected_cell,
    outlier_cycle_index=IQR_outlier_index_dVdQ)

# Generate custom confusion matrix
axplot = modval.generate_confusion_matrix(
    y_true=df_eval_outlier_iqr_dVdQ["true_outlier"],
    y_pred=df_eval_outlier_iqr_dVdQ["pred_outlier"])

fig_title=(r"IQR on $\log(d\textrm{V}d\textrm{Q}_\textrm{scaled,max,cyc})$ \newline")

axplot.set_title(
    fig_title 
    + "\n",
    fontsize=16)

output_fig_filename = (
    "iqr_conf_matrix_dvdq_" 
    + selected_cell_label 
    + ".png")

fig_output_path = (
    selected_cell_artifacts_dir
    .joinpath(output_fig_filename))

plt.savefig(
    fig_output_path,
    dpi=600,
    bbox_inches="tight")

plt.show()

# %% [markdown]
# # Visualize potential anomalous cycles
#
# ## Multiple anomalous cycles
#
# * Plot and annotate multiple potential outlier cycles.

# %%
bviz.plot_multiple_outlier_cycles(
    df_selected_cell,
    potential_outlier_cycles= [0, 40],
    selected_cell_label=selected_cell_label)
# Out:
# Total subplot: 2
# Total rows: 1
# Total columns: 2
# **********************************************************************
# Plot outlier cycle: 0
# Plot outlier cycle: 40

# %% [markdown]
# ## Single anomalous cycle
#
# * Plot and annotate a single cycle as a potential outlier.

# %%
bviz.plot_single_outlier_cycle(
    df_selected_cell,
    selected_cycle_index=147,
    selected_cell_label=selected_cell_label)

# %% [markdown]
# # Plot cycle data with true outliers

# %%
# Import the BenchDB class
# Load only the dataset based on the selected cell
benchdb = BenchDB(
    db_filepath,
    selected_cell_label)

# load the benchmarking dataset
df_selected_cell = benchdb.load_benchmark_dataset(
    dataset_type="train")

if df_selected_cell is not None:

    filter_col = [
        "cell_index",
        "cycle_index",
        "discharge_capacity",
        "voltage"]

    # Drop true labels from the benchmarking dataset
    # and filter for selected columns only
    df_selected_cell_without_labels = benchdb.drop_labels(
        df_selected_cell,
        filter_col)

    # print a subset of the dataframe
    # for diagnostics running in terminals
    print(df_selected_cell_without_labels.head(10).to_markdown())
    print("*"*100)

    # Extract true outliers cycle index from benchmarking dataset
    true_outlier_cycle_index = benchdb.get_true_outlier_cycle_index(
        df_selected_cell)
    print(f"True outlier cycle index:")
    print(true_outlier_cycle_index)
# Out:
# Database is found in the given filepath.
# Loading benchmarking dataset now...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ****************************************************************************************************
# |    | cell_index                    |   cycle_index |   discharge_capacity |   voltage |
# |---:|:------------------------------|--------------:|---------------------:|----------:|
# |  0 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          1.26512e-05 |   3.29189 |
# |  1 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00136774  |   3.28185 |
# |  2 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00292998  |   3.27788 |
# |  3 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00449361  |   3.27513 |
# |  4 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00449361  |   3.27513 |
# |  5 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00605927  |   3.27299 |
# |  6 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.00762155  |   3.27124 |
# |  7 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0091859   |   3.2703  |
# |  8 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0107469   |   3.26875 |
# |  9 | 2017-05-12_5_4C-70per_3C_CH17 |             0 |          0.0123127   |   3.26787 |
# ****************************************************************************************************
# True outlier cycle index:
# [  0.  40. 147. 148.]

# %%
# Plot cell data with true anomalies
benchdb.plot_cycle_data(
    df_selected_cell_without_labels,
    true_outlier_cycle_index)

plt.show()
